# %% [markdown]
# **ONEPLUS**

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in c:\users\hp\miniconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hp\miniconda3\lib\site-packages (from nltk) (1.4.2)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2025.9.1-cp312-cp312-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/41.5 kB ? eta -:--:--
#      ---------------------------- --------- 30.7/41.5 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.5 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.5 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.5 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.5 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.5 kB 217.9 kB/s eta 0:00:01
#      ---------------------------- --------- 30.7/41.5 kB 217.9 kB/s eta 0:00:01
#      --------------------------------------- 41.5/41.5 kB 71.4 kB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\hp\miniconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\hp\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.5 MB 660.6 kB/s eta 0:00:03
#    - -------------------------------------- 0.1/1.5 MB 787.7 kB/s eta 0:00:02
#    --- ------------------------------------ 0.1/1.5 MB 798.9 kB/s eta 0:00:02
#    ------ --------------------------------- 0.2/1.5 MB 1.2 MB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.5 MB 1.9 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.6/1.5 MB 2.3 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.5 MB 3.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.4/1.5 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.5 MB/s eta 0:00:00
# Downloading regex-2025.9.1-cp312-cp312-win_amd64.whl (275 kB)
#    ---------------------------------------- 0.0/275.5 kB ? eta -:--:--
#    ------------------------------- ------- 225.3/275.5 kB 14.3 MB/s eta 0:00:01
#    ---------------------------------------- 275.5/275.5 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.9.1 regex-2025.9.1

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# True

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.14.1-py3-none-any.whl.metadata (5.7 kB)
# Downloading emoji-2.14.1-py3-none-any.whl (590 kB)
#    ---------------------------------------- 0.0/590.6 kB ? eta -:--:--
#     --------------------------------------- 10.2/590.6 kB ? eta -:--:--
#     --------------------------------------- 10.2/590.6 kB ? eta -:--:--
#     --------------------------------------- 10.2/590.6 kB ? eta -:--:--
#    -- ------------------------------------ 30.7/590.6 kB 146.3 kB/s eta 0:00:04
#    -- ------------------------------------ 41.0/590.6 kB 151.3 kB/s eta 0:00:04
#    ---- ---------------------------------- 61.4/590.6 kB 204.8 kB/s eta 0:00:03
#    ------- ------------------------------ 112.6/590.6 kB 312.2 kB/s eta 0:00:02
#    --------- ---------------------------- 143.4/590.6 kB 355.0 kB/s eta 0:00:02
#    ---------------- --------------------- 256.0/590.6 kB 582.4 kB/s eta 0:00:01
#    ---------------------------- --------- 450.6/590.6 kB 938.8 kB/s eta 0:00:01
#    ---------------------------------------  583.7/590.6 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 590.6/590.6 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.14.1

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji
from pathlib import Path


nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)

INPUT_FILE = Path(r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_merged.csv")
OUTPUT_FILE = Path(r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_cleaned.csv")

def remove_emojis(text: str) -> str:
    """Remove emojis from text."""
    return emoji.replace_emoji(text, replace='')

def remove_special_characters(text: str) -> str:
    """Remove special characters, punctuation, and digits."""
    return re.sub(r'[^a-zA-Z\s]', '', text)

def normalize_text(text: str) -> str:
    """Convert to lowercase, clean, and normalize spacing."""
    text = str(text).lower()
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub(r'\s+', ' ', text).strip()
    return text

def clean_reviews(df: pd.DataFrame, column: str = 'Review') -> pd.DataFrame:
    """Clean and preprocess reviews column."""
    if column not in df.columns:
        raise ValueError(f"Column '{column}' not found in DataFrame.")

    df = df.dropna(subset=[column]).copy()

    df['Cleaned_Review'] = df[column].apply(normalize_text)

    stop_words = set(stopwords.words('english'))
    df['Cleaned_Review'] = df['Cleaned_Review'].apply(
        lambda x: ' '.join(word for word in x.split() if word not in stop_words)
    )

    lemmatizer = WordNetLemmatizer()
    df['Cleaned_Review'] = df['Cleaned_Review'].apply(
        lambda x: ' '.join(lemmatizer.lemmatize(word) for word in x.split())
    )

    return df
def main():
    df = pd.read_csv(INPUT_FILE)
    df_cleaned = clean_reviews(df, column='Review')
    df_cleaned.to_csv(OUTPUT_FILE, index=False)
    print(f"✅ Data cleaning completed successfully. File saved at: {OUTPUT_FILE}")

if __name__ == "__main__":
    main()
# Out:
# ✅ Data cleaning completed successfully. File saved at: C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_cleaned.csv

# %%
# !pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      ---------------------------------------- 0.0/622.8 kB ? eta -:--:--
#       --------------------------------------- 10.2/622.8 kB ? eta -:--:--
#       --------------------------------------- 10.2/622.8 kB ? eta -:--:--
#       --------------------------------------- 10.2/622.8 kB ? eta -:--:--
#      - ----------------------------------- 30.7/622.8 kB 119.1 kB/s eta 0:00:05
#      - ----------------------------------- 30.7/622.8 kB 119.1 kB/s eta 0:00:05
#      -- ---------------------------------- 41.0/622.8 kB 130.7 kB/s eta 0:00:05
#      ---- -------------------------------- 81.9/622.8 kB 241.3 kB/s eta 0:00:03
#      -------- --------------------------- 143.4/622.8 kB 387.0 kB/s eta 0:00:02
#      ------------- ---------------------- 225.3/622.8 kB 550.0 kB/s eta 0:00:01
#      -------------------- --------------- 358.4/622.8 kB 794.9 kB/s eta 0:00:01
#      ---------------------------- ------- 491.5/622.8 kB 992.3 kB/s eta 0:00:01
#      -------------------------------------  614.4/622.8 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 622.8/622.8 kB 1.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py): started
#   Building wheel for autocorrect (setup.py): finished with status 'done'
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622375 sha256=0043e49ffb70a1c9652bdf27e114e945434d983666ebdd4d1fe118f9c08ea585
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\b6\28\c2\9ddf8f57f871b55b6fd0ab99c887531fb9a66e5ff236b82aee
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
from autocorrect import Speller

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_cleaned.csv"
df = pd.read_csv(file_path)

# Initialize spell checker
spell = Speller(lang='en')

# Function to correct spelling (safe version)
def correct_spelling(text):
    try:
        return ' '.join(spell(word) for word in str(text).split())
    except Exception:
        return text  # fallback in case of unexpected errors

# Apply spell correction
df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the result
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# Data cleaning and spell correction completed and saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# File paths
input_file = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_autocorrected.csv"
output_file = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_final.csv"

# Load the data
df = pd.read_csv(input_file)

# Copy the autocorrected reviews into a working column
df["Reviews"] = df["Autocorrected_Review"].astype(str)

# Common abbreviations and their replacements
abbreviation_dict = {
    "camara": "camera",
    "fps": "frames per second",
    "oplus": "oneplus",
    "sd gen": "snapdragon generation",
    "superb": "super",
    "professor": "processor",
    "sound college": "sound quality",
    "dam": "damn",
    "opp": "oppo",
    "aws": "awesome",
    "vry gd": "very good",
    "supppoppp": "super",
    "prosesar": "processor",
    "approx hr sot": "approximately hour screen on time",
    "u": "you",
    "hr": "hour",
    "prosper": "processor",
    "usa": "usage",
    "good pro": "good product",
    "gd": "good",
    "nice prod": "nice product",
    "p": "performance",
    "ui": "user interface",
    "day us": "day usage",
    "flipcart": "flipkart",
    "battery beast": "battery best",
    "ease": "easy",
    "pub": "pubg",
    "osm": "awesome",
    "worth karma worthuuu": "worth the money",
    "ois": "optical image stabilization",
    "aim happy": "i am happy",
    "pub cod": "pubg, call of duty",
    "hz": "hertz",
    "degree census": "degree celsius",
    "nd": "and",
    "hit issue": "heating issue",
    "ai": "artificial intelligence",
    "wil": "will",
    "tax": "thanks",
    "anthem": "item",
    "mint camera": "main camera",
    "heat throttle": "heating and throttling",
    "ill update": "i will update",
    "phone devils aswoome": "phone device is awesome",
    "hdr": "high dynamic range",
    "fo": "for",
    "op ti really": "oneplus really",
    "one plus ph": "oneplus phone",
    "spr": "super",
    "apprehension": "appreciation",
    "max": "maximum",
    "oxygen o": "oxygen os",
    "kinda": "kind of",
    "medio": "mediocre",
    "btw": "by the way",
    "assam": "awesome",
    "ph": "phone",
    "bos": "range boost",
    "beast": "best",
    "dlr": "dslr",
    "batter": "better",
    "cod": "call of duty",
    "nyc": "nice",
    "unvilevebale item": "unbelievable item",
    "supper": "super",
    "op": "oneplus",
    "le": "less",
    "assume": "awesome",
    "osm dolly atoms": "awesome dolby atmos",
    "mic failed": "microphone failed",
    "premium paper": "premium feel",
    "ver": "very",
    "gonna": "going to",
    "gun": "good",
    "jus": "just",
    "ive": "i have",
    "extent": "excellent",
    "nice hoon": "nice phone",
    "gr": "great",
    "math": "match",
    "bt": "but",
    "ok": "okay"
}

# Replace abbreviations
for short, full in abbreviation_dict.items():
    df["Reviews"] = df["Reviews"].str.replace(rf"\b{re.escape(short)}\b", full, regex=True, case=False)

# Words we want to drop completely
unwanted_words = [
    "euuuuuuuuuuuuuu", "imei", "xx", "o", "p", "k", "x", "w", "st",
    "isbn", "gb", "min", "mah", "x x x", "makhan", "bim", "rd", "r",
    "n", "nd", "mm", "fish", "apple ka bar", "mp", "ppi", "yrr"
]

def remove_unwanted(text: str) -> str:
    pattern = r"\b(" + "|".join(re.escape(w) for w in unwanted_words) + r")\b"
    return re.sub(pattern, "", text, flags=re.IGNORECASE)

df["Reviews"] = df["Reviews"].apply(remove_unwanted)

# Save results
df.to_csv(output_file, index=False)
print(f"Corrections applied. File saved to: {output_file}")
# Out:
# Corrections applied. File saved to: C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_final.csv

# %% [markdown]
# **OPPO**

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Load the data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_merged.csv"
df = pd.read_csv(file_path)

# Handle missing values
# Drop rows where the Reviews text is missing
df.dropna(subset=['Review'], inplace=True)

# Ensure all entries in the Reviews column are strings
df['Review'] = df['Review'].astype(str)

# Remove emojis using the emoji library
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')

# Remove special characters and digits
def remove_special_characters(text):
    return re.sub('[^a-zA-Z\s]', '', text)

# Normalize the text
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    return text

# Apply normalization
df['Cleaned_Review'] = df['Review'].apply(normalize_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Apply lemmatization
lemmatizer = WordNetLemmatizer()
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_reviews_cleaned.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning completed and saved to", output_file_path)
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_2744\1808887852.py:25: SyntaxWarning: invalid escape sequence '\s'
#   return re.sub('[^a-zA-Z\s]', '', text)
# C:\Users\HP\AppData\Local\Temp\ipykernel_2744\1808887852.py:32: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)  # Remove extra spaces
# Data cleaning completed and saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_reviews_cleaned.csv

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_reviews_cleaned.csv")
df.isnull().sum()
# Out:
# Product_Name      0
# Product_Link      0
# Product_Price     0
# Review            0
# Rating            0
# Cleaned_Review    5
# dtype: int64

# %%
# Display the number of missing values in each column
print("Missing values before dropping:\n", df.isnull().sum())

# Drop rows where 'Cleaned_Review' is missing
df.dropna(subset=['Cleaned_Review'], inplace=True)

# Display the number of missing values after dropping
print("Missing values after dropping:\n", df.isnull().sum())
# Out:
# Missing values before dropping:
#  Product_Name      0
# Product_Link      0
# Product_Price     0
# Review            0
# Rating            0
# Cleaned_Review    5
# dtype: int64
# Missing values after dropping:
#  Product_Name      0
# Product_Link      0
# Product_Price     0
# Review            0
# Rating            0
# Cleaned_Review    0
# dtype: int64

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_reviews_cleaned.csv"
df = pd.read_csv(file_path)

# Fill NaN values with an empty string
df['Cleaned_Review'].fillna('', inplace=True)

# Ensure all entries in the Cleaned_Review column are strings
df['Cleaned_Review'] = df['Cleaned_Review'].astype(str)

# Apply autocorrect using autocorrect library
spell = Speller(lang='en')

def correct_spelling(text):
    return ' '.join([spell(word) for word in text.split()])

# Apply spelling correction
df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2744\1869241045.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cleaned_Review'].fillna('', inplace=True)
# Data cleaning and spell correction completed and saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# Load the cleaned data"
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_reviews_autocorrected.csv"
df = pd.read_csv(file_path)

# Create a new column 'Reviews' based on 'Autocorrected_Reviews'
df['Reviews'] = df['Autocorrected_Review']

# Dictionary of specific abbreviations and their corrections
abbreviation_dict = {
    'camara': 'camera','fps': 'frames per second','oplus': 'oneplus','sd gen': 'snapdragon generation', 'superb': 'super',
    'professor': 'processor','sound college': 'sound quality','dam': 'damn','opp': 'oppo','aws': 'awesome',
    'vry gd': 'very good','supppoppp': 'super','prosesar': 'processor','approx hr sot': 'approximately hour screen on time',
    'u': 'you','hr': 'hour','prosper': 'processor','usa': 'usage','good pro': 'good product','gd': 'good',
    'nice prod': 'nice product','p': 'performance','ui': 'user interface','day us': 'day usage','prosesar': 'processor',
    'flipcart': 'flipkart','battery beast': 'battery best','ease': 'easy','pub': 'pubg','osm': 'awesome',
    'worth karma worthuuu': 'worth the money','ois': 'optical image stabilization','aim happy': 'i am happy',
    'pub cod': 'pubg, call of duty','hz': 'hertz','degree census': 'degree celsius','nd': 'and',
    'hit issue': 'heating issue','ai': 'artificial intelligence','wil': 'will','tax': 'thanks', 'anthem': 'item',
    'mint camera': 'main camera','heat throttle': 'heating and throttling','ill update': 'i will update',
    'phone devils aswoome': 'phone device is awesome','hdr': 'high dynamic range','fo': 'for',
    'op ti really': 'oneplus really','one plus ph': 'oneplus phone','spr': 'super','apprehension': 'appreciation',
    'max': 'maximum','oxygen o': 'oxygen os','kinda': 'kind of','medio': 'mediocre','btw': 'by the way','assam': 'awesome',
    'ph': 'phone','bos': 'range boost','beast': 'best','dlr': 'dslr','batter': 'better','cod': 'call of duty','nyc': 'nice',
    'unvilevebale item': 'unbelievable item','supper': 'super','op': 'oneplus','assume': 'awesome',
    'osm dolly atoms': 'awesome dolby atmos','mic failed': 'microphone failed','premium paper': 'premium feel','ver': 'very',
    'gonna': 'going to', 'pub': 'pubg', 'gun': 'good','jus': 'just','ive': 'i have','extent': 'excellent','nice hoon': 'nice phone',
    'gr': 'great','math': 'match','bt': 'but','ok':'okay', 'costa': 'costar', 'beast': 'best', 'hr': 'hour','sha': 'should',
    'wk': 'week', "hadnt": "had not","im": "i am","havent": "have not", "hasnt": "has not", 'u': "you", 'r': "are",
    "ui": "user interface", "doesnt": "does not", 'rambling': "rumbling", "io": "iphone operating system", 
    "sot": "special operation team", "le": "less", "fhd": "full high definition", "dont": "do not",
    "cam": "camera", "came": "camera", "avg": "average","yea": "yeah", "lil": "little", 
    "costlier": "more expensive", "it's": "it is", "very": "very", "n": "and", "cant": "cannot", "dis": "this", "v": "we", 
    "hdr": 'high dynamic range', "didnt": "did not", "ive": "i have", "bezel": "bezel", "ur": "your", "wont": 'will not', 
    "hd": 'high definition', 'cleanui': "clean user interface", "tatics": "haptics", "sd": "secure digital", "gen": "generation", 
    "usp": 'unique selling proposition', 'degc': "degree celsius", "tatic": "haptic", "unbuilt": "inbuilt", 'xiomi': "xiaomi",
    'regreating': "regretting", 'fyi': "for your information", 'issuehrs': "issue hours", 'doomed': "zoomed",
    'ois': "optical image stabilization", 'theyll': "they will", 'ig': "instagram", 'bbd': "bigger better deal", 'cemra': "camera", 
    'fastly': "fast", "optimise": 'optimize', 'osum': 'awesome', 'vi': "vodafone", 'upi': "unified payments interface",
    'eyeturner': "eye turner", 'banger': "banger", 're': "resolution", 'goddamn': "goddamn", 'aint': "am not", 'plesently': "pleasantly", 
    'thik': "think", "tooo": "too", "uisvery": 'user interface very', 'gif': "graphics interchange format", 'siz': "six", 
    'costlier': "costlier", 'iphones': "iphone", 'youre': 'you are', 'doubtbut': "doubt but", 'phome': "phone", 'red': "redmi", 
    'okif': "okay if", 'pic': "picture", 'smatter': 'smarter', 'membrane': "ambrane", "holdnew": 'hold new', 'swine': "swipe", 
    'inshot': "inshot", 'pixelated': "pixel related", 'cameraai': "camera artificial intelligence", 'oppos': 'oppo', 'amaze': "amazing", 
    'daytoday': "day to day", 'offmy': "off my", 'laggy': "lag", 'victus': "victus", 'slowlike': "slow like",
    'wholeday': "full day",'commendable': "recommendable",'baku': "vaku", 
    'beat': "best", 'surfed': "suffered", 'bgmi': "battle ground mobile india",'isnt': "is not", 
    'flickering': "flickering", 'least': "at least", 'doun': "down", 'thats': "that is", 'ill': "i will", 'bout': "about", 
    'butter': "better", 'emi': "equated monthly installment", 'prefect': "perfect", 'ketone': "keyone", 
    'ie': "in other words", 'cuz': "because","youve": "you have",'ott': "over the top", 
    'oct': "october", 'ois': "optical image stabilization", 'ip': "iphone", 'nowhope': "now hope", 'red': "redmi",
    "eraserunblur": "eraser focus", "wifi": "wireless fidelity", 'ok': "okay", 'hiccup': "hiccup",
    'janso': "january so", 'mahmaybe': "milliampere hour may be", 'lovable': "lovable", 'etc': "et cetera","karma": "varma",
    'dayyyyyyyy': "day", 'pic': "picture", 'camra': "camera", 'Vry': "very", 'easilllyy': "easily",
    'came': "camera", 'mob': "mobile", 'flipcard': "flipkart", 'Kkk': "okay",'swimmer':'shimmery'
    # Add more abbreviations and corrections as needed
}

# Replace abbreviations in the Reviews column
for abbrev, full_form in abbreviation_dict.items():
    # Use word boundaries to ensure whole words are replaced
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + abbrev + r'\b', full_form, case=False, regex=True)

# Unwanted words to remove
unwanted_words = ['euuuuuuuuuuuuuu', 'imei','xx','o', 'p', 'k', 'x', 'w', 'st', 'isbn', 'gb', 'min', 'mah', 'x x x', 'makhan','bim', 'rd', 'r',
                  'n', 'nd', 'mm', 'fish', 'apple ka bar', 'mp', 'ppi', 'yrr', 'imei','k', 'science', 'x', 'nd', 'rd', 'le', 'st', 'p', 'pm', 'f',
                  'tho', 'h', 'th', 'gn', 'xr', 'xl', 'am', 'tg', 'p', 'z','ce', 'ip', 'lt', 'td', 'gt', 'lea', 'la', 'der', 'ir', 'j',
                  'sp', 'th', 'v', 'cg', 'wee', 'seg','g','pro'
]

# Remove unwanted words
for word in unwanted_words:
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + word + r'\b', '', case=False, regex=True)

# Save the updated DataFrame to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_reviews_final.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaned and saved successfully.")
# Out:
# Data cleaned and saved successfully.

# %% [markdown]
# **HONOR**

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Load the data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\honor_merged.csv"
df = pd.read_csv(file_path)

# Handle missing values
# Drop rows where the Reviews text is missing
df.dropna(subset=['Review'], inplace=True)

# Ensure all entries in the Reviews column are strings
df['Review'] = df['Review'].astype(str)

# Remove emojis using the emoji library
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')

# Remove special characters and digits
def remove_special_characters(text):
    return re.sub('[^a-zA-Z\s]', '', text)

# Normalize the text
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    return text

# Apply normalization
df['Cleaned_Review'] = df['Review'].apply(normalize_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Apply lemmatization
lemmatizer = WordNetLemmatizer()
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Honor_reviews_cleaned.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning completed and saved to", output_file_path)
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_2744\1230458216.py:25: SyntaxWarning: invalid escape sequence '\s'
#   return re.sub('[^a-zA-Z\s]', '', text)
# C:\Users\HP\AppData\Local\Temp\ipykernel_2744\1230458216.py:32: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)  # Remove extra spaces
# Data cleaning completed and saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Honor_reviews_cleaned.csv

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Honor_reviews_cleaned.csv"
df = pd.read_csv(file_path)

# Fill NaN values with an empty string
df['Cleaned_Review'].fillna('', inplace=True)

# Ensure all entries in the Cleaned_Review column are strings
df['Cleaned_Review'] = df['Cleaned_Review'].astype(str)

# Apply autocorrect using autocorrect library
spell = Speller(lang='en')

def correct_spelling(text):
    return ' '.join([spell(word) for word in text.split()])

# Apply spelling correction
df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Honor_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2744\4125457083.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cleaned_Review'].fillna('', inplace=True)
# Data cleaning and spell correction completed and saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Honor_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# Load the cleaned data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Honor_reviews_autocorrected.csv"
df = pd.read_csv(file_path)

# Create a new column 'Reviews' based on 'Autocorrected_Reviews'
df['Reviews'] = df['Autocorrected_Review']

# Dictionary of specific abbreviations and their corrections
abbreviation_dict = {
    'camara': 'camera', 'fps': 'frames per second', 'oplus': 'oneplus', 'sd gen': 'snapdragon generation', 'superb': 'super',
    'professor': 'processor', 'sound college': 'sound quality', 'dam': 'damn', 'opp': 'oppo', 'aws': 'awesome',
    'vry gd': 'very good', 'supppoppp': 'super', 'prosesar': 'processor', 'approx hr sot': 'approximately hour screen on time',
    'u': 'you', 'hr': 'hour', 'prosper': 'processor', 'usa': 'usage', 'good pro': 'good product', 'gd': 'good',
    'nice prod': 'nice product', 'p': 'performance', 'ui': 'user interface', 'day us': 'day usage', 'prosesar': 'processor',
    'flipcart': 'flipkart', 'battery beast': 'battery best', 'ease': 'easy', 'pub': 'pubg', 'osm': 'awesome',
    'worth karma worthuuu': 'worth the money', 'ois': 'optical image stabilization', 'aim happy': 'i am happy',
    'pub cod': 'pubg, call of duty', 'hz': 'hertz', 'degree census': 'degree celsius', 'nd': 'and',
    'hit issue': 'heating issue', 'ai': 'artificial intelligence', 'wil': 'will', 'tax': 'thanks', 'anthem': 'item',
    'mint camera': 'main camera', 'heat throttle': 'heating and throttling', 'ill update': 'i will update',
    'phone devils aswoome': 'phone device is awesome', 'hdr': 'high dynamic range', 'fo': 'for',
    'op ti really': 'oneplus really', 'one plus ph': 'oneplus phone', 'spr': 'super', 'apprehension': 'appreciation',
    'max': 'maximum', 'oxygen o': 'oxygen os', 'kinda': 'kind of', 'medio': 'mediocre', 'btw': 'by the way', 'assam': 'awesome',
    'ph': 'phone', 'bos': 'range boost', 'beast': 'best', 'dlr': 'dslr', 'batter': 'better', 'cod': 'call of duty', 'nyc': 'nice',
    'unvilevebale item': 'unbelievable item', 'supper': 'super', 'op': 'oneplus', 'assume': 'awesome',
    'osm dolly atoms': 'awesome dolby atmos', 'mic failed': 'microphone failed', 'premium paper': 'premium feel', 'ver': 'very',
    'gonna': 'going to', 'pub': 'pubg', 'gun': 'good', 'jus': 'just', 'ive': 'i have', 'extent': 'excellent', 'nice hoon': 'nice phone',
    'gr': 'great', 'math': 'match', 'bt': 'but', 'ok':'okay', 'costa': 'costar', 'beast': 'best', 'hr': 'hour', 'sha': 'should',
    'wk': 'week', "hadnt": "had not", "im": "i am", "havent": "have not", "hasnt": "has not", 'u': "you", 'r': "are",
    "ui": "user interface", "doesnt": "does not", 'rambling': "rumbling", "io": "iphone operating system", 
    "sot": "special operation team", "le": "less", "fhd": "full high definition", "dont": "do not",
    "cam": "camera", "came": "camera", "avg": "average", "yea": "yeah", "lil": "little", 
    "costlier": "more expensive", "it's": "it is", "very": "very", "n": "and", "cant": "cannot", "dis": "this", "v": "we", 
    "hdr": 'high dynamic range', "didnt": "did not", "ive": "i have", "bezel": "bezel", "ur": "your", "wont": 'will not', 
    "hd": 'high definition', 'cleanui': "clean user interface", "tatics": "haptics", "sd": "secure digital", "gen": "generation", 
    "usp": 'unique selling proposition', 'degc': "degree celsius", "tatic": "haptic", "unbuilt": "inbuilt", 'xiomi': "xiaomi",
    'regreating': "regretting", 'fyi': "for your information", 'issuehrs': "issue hours", 'doomed': "zoomed",
    'ois': "optical image stabilization", 'theyll': "they will", 'ig': "instagram", 'bbd': "bigger better deal", 'cemra': "camera", 
    'fastly': "fast", "optimise": 'optimize', 'osum': 'awesome', 'vi': "vodafone", 'upi': "unified payments interface",
    'eyeturner': "eye turner", 'banger': "banger", 're': "resolution", 'goddamn': "goddamn", 'aint': "am not", 'plesently': "pleasantly", 
    'thik': "think", "tooo": "too", "uisvery": 'user interface very', 'gif': "graphics interchange format", 'siz': "six", 
    'costlier': "costlier", 'iphones': "iphone", 'youre': 'you are', 'doubtbut': "doubt but", 'phome': "phone", 'red': "redmi", 
    'okif': "okay if", 'pic': "picture", 'smatter': 'smarter', 'membrane': "ambrane", "holdnew": 'hold new', 'swine': "swipe", 
    'inshot': "inshot", 'pixelated': "pixel related", 'cameraai': "camera artificial intelligence", 'oppos': 'oppo', 'amaze': "amazing", 
    'daytoday': "day to day", 'offmy': "off my", 'laggy': "lag", 'victus': "victus", 'slowlike': "slow like",
    'wholeday': "full day", 'commendable': "recommendable", 'baku': "vaku", 
    'beat': "best", 'surfed': "suffered", 'bgmi': "battle ground mobile india", 'isnt': "is not", 
    'flickering': "flickering", 'least': "at least", 'doun': "down", 'thats': "that is", 'ill': "i will", 'bout': "about", 
    'butter': "better", 'emi': "equated monthly installment", 'prefect': "perfect", 'ketone': "keyone", 
    'ie': "in other words", 'cuz': "because", "youve": "you have", 'ott': "over the top", 
    'oct': "october", 'ois': "optical image stabilization", 'ip': "iphone", 'nowhope': "now hope", 'red': "redmi",
    "eraserunblur": "eraser focus", "wifi": "wireless fidelity", 'ok': "okay", 'hiccup': "hiccup",
    'janso': "january so", 'mahmaybe': "milliampere hour may be", 'lovable': "lovable", 'etc': "et cetera", "karma": "varma",
    'dayyyyyyyy': "day", 'pic': "picture", 'camra': "camera", 'Vry': "very", 'easilllyy': "easily",
    'came': "camera", 'mob': "mobile", 'flipcard': "flipkart", 'Kkk': "okay", 'swimmer': 'shimmery', 'supeeeeer': 'super', 'ur': 'your', 'nais': 'nice', 'descent': 'decent', 'se user': 'super', 'nris': 'nice',
    'suuuuuuuuuuuuuuper': 'super', 'project': 'product', 'xtra': 'extra', 'userniterface': 'user interface', 'prossecer': 'processor', 'amazingest': 'amazing',
    'col': 'color', 'superbbbbb': 'superb', 'goog': 'good', 'censor': 'sensor', 'ram': 'ram', 'wwwhhhoooooooo': 'who', 'pictre': 'picture', 'comera': 'camera', 'fa': 'for',
    'truely': 'truly', 'fonnne': 'phone', 'excellant': 'excellent', 'totallly': 'totally', 'ceramicback': 'ceramic back', 'internat': 'internet', 'iui': 'miui', 'camaera': 'camera', 'supper': 'super',
    'exllent': 'excellent', 'magnafiqui': 'magnificent', 'affecfordble': 'affordable', 'smmmmooooothhhhhh': 'smooth', 'veryg': 'very good', 'camaera': 'camera',
    'ar': 'are', 'eet': 'get', 'june': 'june', 'ster': 'star', 'osam': 'awesome', 'gona': 'gonna', 'suchh': 'such', 'amoled': 'amoled', 'fon': 'phone', 'ram': 'ram', 'exp': 'expensive',
    'xclent': 'excellent', 'ans': 'and', 'shotcut': 'shortcut', 'expoerience': 'experience', 'bgmi': 'battle grounds mobile india', 'anr': 'and', 'whao': 'wow', 'awesomeeee': 'awesome', 'blurr': 'blur',
    'definately': 'definitely', 'suuuuper': 'super', 'nize': 'nice', 'phobe': 'phone', 'thanksflipcart': 'thanks flipkart', 'mimax': 'mi max', 'picure': 'picture', 'blutooth': 'bluetooth', 'qhy': 'why',
    'user interfce': 'user interface', 'beasutiful': 'beautiful', 'smother': 'smoother', 'gooddd': 'good', 'ramgood': 'ram good', 'smother': 'smoother', 'suggestable': 'suggestible', 'gamesro': 'games to',
    'playbles': 'playable', 'fes': 'fest', 'crystalclear': 'crystal clear', 'ph': 'phone', 'frimeware': 'firmware', 'dowload': 'download', 'camara': 'camera', 'gud': 'good', 'jio': 'jio', 'againflipkart': 'again flipkart',
    'imposible': 'impossible', 'comfortbale': 'comfortable', 'whith': 'with', 'chages': 'changes', 'consiser': 'consider', 'heatsup': 'heats up', 'grt': 'great', 'fringerprint': 'fingerprint', 'detailingg': 'detailing',
    'gud': 'good', 'hz': 'hertz', 'nd': 'and', 'soundcollage': 'sound quality', 'wi': 'with', 'appreciateble': 'appreciable', 'phn': 'phone', 'mu': 'music', 'preforance': 'performance', 'veryyy': 'very',
    'ceramicback': 'ceramic back', 'ceraicback': 'ceramic back', 'battrey': 'battery', 'hollywow': 'hollywood', 'expirence': 'experience', 'niceui': 'nice user interface', 'terriffic': 'terrific', 'varien': 'variant',
    'xcellent': 'excellent', 'sorring': 'scoring', 'comfrtable': 'comfortable', 'mics': 'microphones', 'cds': 'cd', 'whot': 'what', 'mindbloing': 'mind blowing', 'gamesome': 'games on', 'fluently': 'fluent',
    'dat': 'that', 'amasing': 'amazing', 'superrr': 'super', 'osm': 'awesome', 'hreat': 'great', 'costefficeint': 'cost efficient', 'bhaskar': 'bhaskaran', 'heatingproblem': 'heating problem',
    'miracast': 'miracast', 'definately': 'definitely', 'wo': 'would', 'thsnks': 'thanks', 'whywhy': 'why why', 'cam': 'camera', 'gaurantee': 'guarantee', 'crazychaging': 'crazy charging',
    'interfece': 'interface', 'excellant': 'excellent', 'intenation': 'internet', 'bettry': 'battery', 'exellent': 'excellent', 'lockscreen': 'lock screen', 'tap': 'tap', 'eb': 'is',
    'cam': 'camera', 'exellent': 'excellent', 'pros': 'pros', 'cus': 'because', 'definatly': 'definitely', 'microphoneon': 'microphone on', 'renaining': 'remaining', 'nxet': 'next',
    'switcher': 'switcher', 'yooo': 'yo', 'exlent': 'excellent', 'vol': 'volume', 'magic': 'magic', 'beacuse': 'because', 'ven': 'even', 'expence': 'expense', 'pones': 'phones',
    'pu': 'pubg', 'exlent': 'excellent', 'bgmi': 'battle ground mobile india', 'athir': 'arshad', 'ramaining': 'remaining', 'docing': 'docking', 'batterylife': 'battery life', 'batt': 'battery', 
    'cas': 'case', 'proble': 'problem', 'sa': 'sa', 'lense': 'lens', 'cameraof': 'camera of', 'parformance': 'performance', 'whatsapp': 'whatsapp', 'camra': 'camera', 'amoleddisplay': 'amoled display',
    'hugh': 'high', 'exellent': 'excellent', 'phon': 'phone', 'boaring': 'boring', 'sync': 'sync', 'flipkart': 'flipkart', 'tp': 'to', 'displayflipkart': 'display flipkart', 'flipcart': 'flipkart',
    'complain': 'complain', 'sdgen': 'snapdragon generation', 'comerabgmi': 'camera battle ground mobile india', 'doint': 'do not', 'iys': 'it is', 'superp': 'super', 'expeeience': 'experience', 'loook': 'look',
    'couple': 'couple', 'phoneflipkart': 'phone flipkart', 'got': 'got', 'consisency': 'consistency', 'dispkay': 'display', 'proc': 'processor', 'gud': 'good', 'clarityclearity': 'clarity', 'octo': 'octa',
    'excessive': 'excessive', 'goodem': 'good em', 'snapdragon': 'snapdragon', 'camara': 'camera', 'sper': 'super', 'rebooting': 'rebooting', 'accessorry': 'accessory', 'usr': 'user', 'dispkay': 'display',
    'pictureclarity': 'picture clarity', 'dispkayclarity': 'display clarity', 'extremely': 'extremely', 'awsome': 'awesome', 'goodcamera': 'good camera', 'goodclatrity': 'good clarity', 'miui': 'miui',
    'clearn': 'clear', 'cllick': 'click', 'reseting': 'resetting', 'psl': 'psl', 'edxtra': 'extra', 'redmy': 'redmi', 'gamy': 'game', 'biometrics': 'biometrics', 'noney': 'money', 'lenovo': 'lenovo',
    'possessing': 'processing', 'ossam': 'awesome', 'tis': 'this', 'surport': 'support', 'awsom': 'awesome', 'supere': 'super', 'serviceflipkart': 'service flipkart', 'awesomeas': 'awesome', 'greate': 'great',
    'mobs': 'mobile', 'sept': 'september', 'its': 'its', 'wasawsm': 'was awesome', 'flipkartgood': 'flipkart good', 'easeofuse': 'ease of use', 'mi': 'mi', 'perfectperfect': 'perfect', 'ohow': 'oh how',
    'dosn': 'does', 'okkay': 'okay', 'awdome': 'awesome', 'des': 'des', 'awesomefeature': 'awesome feature', 'circa': 'circa', 'gud': 'good', 'backca': 'back cover', 'yhe': 'the', 'niceproduct': 'nice product',
    'me':'mi', 'awesomegod': 'awesome', 'tricking': 'tricking', 'allure': 'allure', 'mia1': 'mi a1', 'backpanel': 'back panel', 'microwave': 'microphone', 'fri': 'friend', 'frusterating': 'frustrating',
    'rs': 'rs', 'chat': 'chat', 'saiz': 'size', 'ram': 'ram', 'workswll': 'works well', 'mid': 'mi', 'ph': 'phone', 'flpkrt': 'flipkart', 'blowming': 'blowing', 'complaince': 'complain', 'ar': 'are', 'phn': 'phone',
    'usb': 'usb', 'coverback': 'cover back', 'awesomecamera': 'awesome camera', 'osame': 'awesome', 'bat': 'battery', 'weighing': 'weighing', 'midrange': 'mid range', 'blowng': 'blowing', 'yoursite': 'your site',
    'superbg': 'superb', 'intetnet': 'internet', 'besutiful': 'beautiful', 'suuuper': 'super', 'ate': 'ate', 'ceramicback': 'ceramic back', 'velvet': 'velvet', 'goog': 'good', 'doeswork': 'does work', 'interrface': 'interface',
    'spellings': 'spellings', 'competetion': 'competition', 'clarityis': 'clarity is', 'xclent': 'excellent', 'crome': 'chrome', 'sinply': 'simply', 'cermaic': 'ceramic', 'plz': 'please', 'compability': 'compatibility',
    'excellnt': 'excellent', 'iui': 'miui', 'ultraa': 'ultra', 'whatsoever': 'whatsoever', 'goodand': 'good and', 'gotcamera': 'got camera', 'ple': 'please', 'afortable': 'affordable', 'kns': 'kms', 'nicefeature': 'nice feature',
    'redemi': 'redmi', 'xxent': 'excellent', 'cuttrt': 'cutout', 'mi': 'mi', 'serires': 'series', 'whish': 'wish', 'dlexo': 'deluxe', 'cristal': 'crystal', 'makesense': 'make sense', 'gud': 'good', 'expellience': 'experience',
    'reflectiion': 'reflection', 'microphone': 'microphone', 'cameraquality': 'camera quality', 'awesomef': 'awesome', 'guddisplay': 'good display', 'frustrting': 'frustrating', 'vol': 'volume', 'cermaic': 'ceramic', 'clearence': 'clearance', 
    'snapdragon': 'snapdragon', 'ceramicback': 'ceramic back', 'cermaicback': 'ceramic back', 'snapdragon820': 'snapdragon 820', 'miui8': 'miui 8', 'snapdragon': 'snapdragon', 'snapdragon': 'snapdragon', 'snapdragon835': 'snapdragon 835', 'snapdragon820': 'snapdragon 820'
}
# Replace abbreviations in the Reviews column
for abbrev, full_form in abbreviation_dict.items():
    # Use word boundaries to ensure whole words are replaced
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + abbrev + r'\b', full_form, case=False, regex=True)

unwanted_words = [
    'euuuuuuuuuuuuuu', 'imei', 'xx', 'o', 'p', 'k', 'x', 'w', 'st', 'isbn', 'gb', 'min', 'mah', 'x x x', 'makhan',
    'bim', 'rd', 'r', 'n', 'nd', 'mm', 'fish', 'apple ka bar', 'mp', 'ppi', 'yrr', 'imei', 'k', 'science', 'x', 'nd',
    'rd', 'le', 'st', 'p', 'pm', 'f', 'tho', 'h', 'th', 'gn', 'xr', 'xl', 'am', 'tg', 'p', 'z', 'ce', 'ip', 'lt', 'td',
    'gt', 'lea', 'la', 'der', 'ir', 'j', 'sp', 'th', 'v', 'cg', 'wee', 'seg', 'g', 'pro', 'x', 'p', 'e', 'opt', 'nfc',
    'tm', 'ir', 'xnd', 'ffd', 'htc', 'cal', 'pm', 'ordo', 'gh', 'rn', 'mia', 'ip', 'sd', 'oct', 'core', 'expos', 'rd',
    'ip', 'pe', 'amp', 'paisa bassol', 'pc', 'al', 'zindabad', 'dnd', 'rsk', 'g', 'ooooooo', 'mmmmmmm', 'ggggggg', 'vfd',
    'havoc', 'ah', 'hi', 'hai', 'swimming', 'gop', 'ji', 'lajawab', 'asap loose', 'ie', 'h ago', 'madathukulam', 'mo', 
    'fea', 'l', 'ex', 'qu', 'Lotus', 'voodoo', 'ko', 'ont', 'maa', 'ag', 'ne', 'quot', 'sakuntala', 'rayagada bissamcuttack',
    'gimmick', 'thi', 'str', 'fatafati', 'mast', 'garcia jharkhand', 'sa', 'isvudn', 'x', 'sg', 'hijab', 'tbh', 'wars', 
    'nts', 'huawei', 'keirin', 'ofc', 'pg', 'sec', 'jaar', 'hai ye', 'th', 'ft', 'emu', 'gpu', 'fr', 'nit', 'eis', 'oo',
    'hh', 'ly', 'fei', 'q', 'c', 'sw', 'kd', 'ofc', 'bl', 'lol', 'et', 'rgh', 'extremewwe', 'dts', 'iu', 'vr', 'Soo', 
    'al', 'sm', 'rsk', 'eta', 'gh', 'nu', 'ota', 'fp'
]
# Remove unwanted words
for word in unwanted_words:
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + word + r'\b', '', case=False, regex=True)

# Save the updated DataFrame to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Honor_reviews_final.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaned and saved successfully.")
# Out:
# Data cleaned and saved successfully.

# %% [markdown]
# **MOTOROLA**

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Load the data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\motorola_merged.csv"
df = pd.read_csv(file_path)

# Handle missing values
# Drop rows where the Reviews text is missing
df.dropna(subset=['Review'], inplace=True)

# Ensure all entries in the Reviews column are strings
df['Review'] = df['Review'].astype(str)

# Remove emojis using the emoji library
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')

# Remove special characters and digits
def remove_special_characters(text):
    return re.sub('[^a-zA-Z\s]', '', text)

# Normalize the text
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    return text

# Apply normalization
df['Cleaned_Review'] = df['Review'].apply(normalize_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Apply lemmatization
lemmatizer = WordNetLemmatizer()
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\motorola_reviews_cleaned.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning completed and saved to", output_file_path)
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_2744\3809124658.py:25: SyntaxWarning: invalid escape sequence '\s'
#   return re.sub('[^a-zA-Z\s]', '', text)
# C:\Users\HP\AppData\Local\Temp\ipykernel_2744\3809124658.py:32: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)  # Remove extra spaces
# Data cleaning completed and saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\motorola_reviews_cleaned.csv

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\motorola_reviews_cleaned.csv"
df = pd.read_csv(file_path)

# Fill NaN values with an empty string
df['Cleaned_Review'].fillna('', inplace=True)

# Ensure all entries in the Cleaned_Review column are strings
df['Cleaned_Review'] = df['Cleaned_Review'].astype(str)

# Apply autocorrect using autocorrect library
spell = Speller(lang='en')

def correct_spelling(text):
    return ' '.join([spell(word) for word in text.split()])

# Apply spelling correction
df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\motorola_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2744\1164687199.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cleaned_Review'].fillna('', inplace=True)
# Data cleaning and spell correction completed and saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\motorola_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# Load the cleaned data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\motorola_reviews_autocorrected.csv"
df = pd.read_csv(file_path)

# Create a new column 'Reviews' based on 'Autocorrected_Reviews'
df['Reviews'] = df['Autocorrected_Review']

# Dictionary of specific abbreviations and their corrections
abbreviation_dict = {
    'camara': 'camera', 'fps': 'frames per second', 'oplus': 'oneplus', 'sd gen': 'snapdragon generation', 'superb': 'super',
    'professor': 'processor', 'sound college': 'sound quality', 'dam': 'damn', 'opp': 'oppo', 'aws': 'awesome',
    'vry gd': 'very good', 'supppoppp': 'super', 'prosesar': 'processor', 'approx hr sot': 'approximately hour screen on time',
    'u': 'you', 'hr': 'hour', 'prosper': 'processor', 'usa': 'usage', 'good pro': 'good product', 'gd': 'good',
    'nice prod': 'nice product', 'p': 'performance', 'ui': 'user interface', 'day us': 'day usage', 'prosesar': 'processor',
    'flipcart': 'flipkart', 'battery beast': 'battery best', 'ease': 'easy', 'pub': 'pubg', 'osm': 'awesome',
    'worth karma worthuuu': 'worth the money', 'ois': 'optical image stabilization', 'aim happy': 'i am happy',
    'pub cod': 'pubg, call of duty', 'hz': 'hertz', 'degree census': 'degree celsius', 'nd': 'and',
    'hit issue': 'heating issue', 'ai': 'artificial intelligence', 'wil': 'will', 'tax': 'thanks', 'anthem': 'item',
    'mint camera': 'main camera', 'heat throttle': 'heating and throttling', 'ill update': 'i will update',
    'phone devils aswoome': 'phone device is awesome', 'hdr': 'high dynamic range', 'fo': 'for',
    'op ti really': 'oneplus really', 'one plus ph': 'oneplus phone', 'spr': 'super', 'apprehension': 'appreciation',
    'max': 'maximum', 'oxygen o': 'oxygen os', 'kinda': 'kind of', 'medio': 'mediocre', 'btw': 'by the way', 'assam': 'awesome',
    'ph': 'phone', 'bos': 'range boost', 'beast': 'best', 'dlr': 'dslr', 'batter': 'better', 'cod': 'call of duty', 'nyc': 'nice',
    'unvilevebale item': 'unbelievable item', 'supper': 'super', 'op': 'oneplus', 'assume': 'awesome',
    'osm dolly atoms': 'awesome dolby atmos', 'mic failed': 'microphone failed', 'premium paper': 'premium feel', 'ver': 'very',
    'gonna': 'going to', 'pub': 'pubg', 'gun': 'good', 'jus': 'just', 'ive': 'i have', 'extent': 'excellent', 'nice hoon': 'nice phone',
    'gr': 'great', 'math': 'match', 'bt': 'but', 'ok':'okay', 'costa': 'costar', 'beast': 'best', 'hr': 'hour', 'sha': 'should',
    'wk': 'week', "hadnt": "had not", "im": "i am", "havent": "have not", "hasnt": "has not", 'u': "you", 'r': "are",
    "ui": "user interface", "doesnt": "does not", 'rambling': "rumbling", "io": "iphone operating system", 
    "sot": "special operation team", "le": "less", "fhd": "full high definition", "dont": "do not",
    "cam": "camera", "came": "camera", "avg": "average", "yea": "yeah", "lil": "little", 
    "costlier": "more expensive", "it's": "it is", "very": "very", "n": "and", "cant": "cannot", "dis": "this", "v": "we", 
    "hdr": 'high dynamic range', "didnt": "did not", "ive": "i have", "bezel": "bezel", "ur": "your", "wont": 'will not', 
    "hd": 'high definition', 'cleanui': "clean user interface", "tatics": "haptics", "sd": "secure digital", "gen": "generation", 
    "usp": 'unique selling proposition', 'degc': "degree celsius", "tatic": "haptic", "unbuilt": "inbuilt", 'xiomi': "xiaomi",
    'regreating': "regretting", 'fyi': "for your information", 'issuehrs': "issue hours", 'doomed': "zoomed",
    'ois': "optical image stabilization", 'theyll': "they will", 'ig': "instagram", 'bbd': "bigger better deal", 'cemra': "camera", 
    'fastly': "fast", "optimise": 'optimize', 'osum': 'awesome', 'vi': "vodafone", 'upi': "unified payments interface",
    'eyeturner': "eye turner", 'banger': "banger", 're': "resolution", 'goddamn': "goddamn", 'aint': "am not", 'plesently': "pleasantly", 
    'thik': "think", "tooo": "too", "uisvery": 'user interface very', 'gif': "graphics interchange format", 'siz': "six", 
    'costlier': "costlier", 'iphones': "iphone", 'youre': 'you are', 'doubtbut': "doubt but", 'phome': "phone", 'red': "redmi", 
    'okif': "okay if", 'pic': "picture", 'smatter': 'smarter', 'membrane': "ambrane", "holdnew": 'hold new', 'swine': "swipe", 
    'inshot': "inshot", 'pixelated': "pixel related", 'cameraai': "camera artificial intelligence", 'oppos': 'oppo', 'amaze': "amazing", 
    'daytoday': "day to day", 'offmy': "off my", 'laggy': "lag", 'victus': "victus", 'slowlike': "slow like",
    'wholeday': "full day", 'commendable': "recommendable", 'baku': "vaku", 
    'beat': "best", 'surfed': "suffered", 'bgmi': "battle ground mobile india", 'isnt': "is not", 
    'flickering': "flickering", 'least': "at least", 'doun': "down", 'thats': "that is", 'ill': "i will", 'bout': "about", 
    'butter': "better", 'emi': "equated monthly installment", 'prefect': "perfect", 'ketone': "keyone", 
    'ie': "in other words", 'cuz': "because", "youve": "you have", 'ott': "over the top", 
    'oct': "october", 'ois': "optical image stabilization", 'ip': "iphone", 'nowhope': "now hope", 'red': "redmi",
    "eraserunblur": "eraser focus", "wifi": "wireless fidelity", 'ok': "okay", 'hiccup': "hiccup",
    'janso': "january so", 'mahmaybe': "milliampere hour may be", 'lovable': "lovable", 'etc': "et cetera", "karma": "varma",
    'dayyyyyyyy': "day", 'pic': "picture", 'camra': "camera", 'Vry': "very", 'easilllyy': "easily",
    'came': "camera", 'mob': "mobile", 'flipcard': "flipkart", 'Kkk': "okay", 'swimmer': 'shimmery', 'supeeeeer': 'super', 'ur': 'your', 'nais': 'nice', 'descent': 'decent', 'se user': 'super', 'nris': 'nice',
    'suuuuuuuuuuuuuuper': 'super', 'project': 'product', 'xtra': 'extra', 'userniterface': 'user interface', 'prossecer': 'processor', 'amazingest': 'amazing',
    'col': 'color', 'superbbbbb': 'superb', 'goog': 'good', 'censor': 'sensor', 'ram': 'ram', 'wwwhhhoooooooo': 'who', 'pictre': 'picture', 'comera': 'camera', 'fa': 'for',
    'truely': 'truly', 'fonnne': 'phone', 'excellant': 'excellent', 'totallly': 'totally', 'ceramicback': 'ceramic back', 'internat': 'internet', 'iui': 'miui', 'camaera': 'camera', 'supper': 'super',
    'exllent': 'excellent', 'magnafiqui': 'magnificent', 'affecfordble': 'affordable', 'smmmmooooothhhhhh': 'smooth', 'veryg': 'very good', 'camaera': 'camera',
    'ar': 'are', 'eet': 'get', 'june': 'june', 'ster': 'star', 'osam': 'awesome', 'gona': 'gonna', 'suchh': 'such', 'amoled': 'amoled', 'fon': 'phone', 'ram': 'ram', 'exp': 'expensive',
    'xclent': 'excellent', 'ans': 'and', 'shotcut': 'shortcut', 'expoerience': 'experience', 'bgmi': 'battle grounds mobile india', 'anr': 'and', 'whao': 'wow', 'awesomeeee': 'awesome', 'blurr': 'blur',
    'definately': 'definitely', 'suuuuper': 'super', 'nize': 'nice', 'phobe': 'phone', 'thanksflipcart': 'thanks flipkart', 'mimax': 'mi max', 'picure': 'picture', 'blutooth': 'bluetooth', 'qhy': 'why',
    'user interfce': 'user interface', 'beasutiful': 'beautiful', 'smother': 'smoother', 'gooddd': 'good', 'ramgood': 'ram good', 'smother': 'smoother', 'suggestable': 'suggestible', 'gamesro': 'games to',
    'playbles': 'playable', 'fes': 'fest', 'crystalclear': 'crystal clear', 'ph': 'phone', 'frimeware': 'firmware', 'dowload': 'download', 'camara': 'camera', 'gud': 'good', 'jio': 'jio', 'againflipkart': 'again flipkart',
    'imposible': 'impossible', 'comfortbale': 'comfortable', 'whith': 'with', 'chages': 'changes', 'consiser': 'consider', 'heatsup': 'heats up', 'grt': 'great', 'fringerprint': 'fingerprint', 'detailingg': 'detailing',
    'gud': 'good', 'hz': 'hertz', 'nd': 'and', 'soundcollage': 'sound quality', 'wi': 'with', 'appreciateble': 'appreciable', 'phn': 'phone', 'mu': 'music', 'preforance': 'performance', 'veryyy': 'very',
    'ceramicback': 'ceramic back', 'ceraicback': 'ceramic back', 'battrey': 'battery', 'hollywow': 'hollywood', 'expirence': 'experience', 'niceui': 'nice user interface', 'terriffic': 'terrific', 'varien': 'variant',
    'xcellent': 'excellent', 'sorring': 'scoring', 'comfrtable': 'comfortable', 'mics': 'microphones', 'cds': 'cd', 'whot': 'what', 'mindbloing': 'mind blowing', 'gamesome': 'games on', 'fluently': 'fluent',
    'dat': 'that', 'amasing': 'amazing', 'superrr': 'super', 'osm': 'awesome', 'hreat': 'great', 'costefficeint': 'cost efficient', 'bhaskar': 'bhaskaran', 'heatingproblem': 'heating problem',
    'miracast': 'miracast', 'definately': 'definitely', 'wo': 'would', 'thsnks': 'thanks', 'whywhy': 'why why', 'cam': 'camera', 'gaurantee': 'guarantee', 'crazychaging': 'crazy charging',
    'interfece': 'interface', 'excellant': 'excellent', 'intenation': 'internet', 'bettry': 'battery', 'exellent': 'excellent', 'lockscreen': 'lock screen', 'tap': 'tap', 'eb': 'is',
    'cam': 'camera', 'exellent': 'excellent', 'pros': 'pros', 'cus': 'because', 'definatly': 'definitely', 'microphoneon': 'microphone on', 'renaining': 'remaining', 'nxet': 'next',
    'switcher': 'switcher', 'yooo': 'yo', 'exlent': 'excellent', 'vol': 'volume', 'magic': 'magic', 'beacuse': 'because', 'ven': 'even', 'expence': 'expense', 'pones': 'phones',
    'pu': 'pubg', 'exlent': 'excellent', 'bgmi': 'battle ground mobile india', 'athir': 'arshad', 'ramaining': 'remaining', 'docing': 'docking', 'batterylife': 'battery life', 'batt': 'battery', 
    'cas': 'case', 'proble': 'problem', 'sa': 'sa', 'lense': 'lens', 'cameraof': 'camera of', 'parformance': 'performance', 'whatsapp': 'whatsapp', 'camra': 'camera', 'amoleddisplay': 'amoled display',
    'hugh': 'high', 'exellent': 'excellent', 'phon': 'phone', 'boaring': 'boring', 'sync': 'sync', 'flipkart': 'flipkart', 'tp': 'to', 'displayflipkart': 'display flipkart', 'flipcart': 'flipkart',
    'complain': 'complain', 'sdgen': 'snapdragon generation', 'comerabgmi': 'camera battle ground mobile india', 'doint': 'do not', 'iys': 'it is', 'superp': 'super', 'expeeience': 'experience', 'loook': 'look',
    'couple': 'couple', 'phoneflipkart': 'phone flipkart', 'got': 'got', 'consisency': 'consistency', 'dispkay': 'display', 'proc': 'processor', 'gud': 'good', 'clarityclearity': 'clarity', 'octo': 'octa',
    'excessive': 'excessive', 'goodem': 'good em', 'snapdragon': 'snapdragon', 'camara': 'camera', 'sper': 'super', 'rebooting': 'rebooting', 'accessorry': 'accessory', 'usr': 'user', 'dispkay': 'display',
    'pictureclarity': 'picture clarity', 'dispkayclarity': 'display clarity', 'extremely': 'extremely', 'awsome': 'awesome', 'goodcamera': 'good camera', 'goodclatrity': 'good clarity', 'miui': 'miui',
    'clearn': 'clear', 'cllick': 'click', 'reseting': 'resetting', 'psl': 'psl', 'edxtra': 'extra', 'redmy': 'redmi', 'gamy': 'game', 'biometrics': 'biometrics', 'noney': 'money', 'lenovo': 'lenovo',
    'possessing': 'processing', 'ossam': 'awesome', 'tis': 'this', 'surport': 'support', 'awsom': 'awesome', 'supere': 'super', 'serviceflipkart': 'service flipkart', 'awesomeas': 'awesome', 'greate': 'great',
    'mobs': 'mobile', 'sept': 'september', 'its': 'its', 'wasawsm': 'was awesome', 'flipkartgood': 'flipkart good', 'easeofuse': 'ease of use', 'mi': 'mi', 'perfectperfect': 'perfect', 'ohow': 'oh how',
    'dosn': 'does', 'okkay': 'okay', 'awdome': 'awesome', 'des': 'des', 'awesomefeature': 'awesome feature', 'circa': 'circa', 'gud': 'good', 'backca': 'back cover', 'yhe': 'the', 'niceproduct': 'nice product',
    'me':'mi', 'awesomegod': 'awesome', 'tricking': 'tricking', 'allure': 'allure', 'mia1': 'mi a1', 'backpanel': 'back panel', 'microwave': 'microphone', 'fri': 'friend', 'frusterating': 'frustrating','moto':'motorola',
    'rs': 'rs', 'chat': 'chat', 'saiz': 'size', 'ram': 'ram', 'workswll': 'works well', 'mid': 'mi', 'ph': 'phone', 'flpkrt': 'flipkart', 'blowming': 'blowing', 'complaince': 'complain', 'ar': 'are', 'phn': 'phone',
    'usb': 'usb', 'coverback': 'cover back', 'awesomecamera': 'awesome camera', 'osame': 'awesome', 'bat': 'battery', 'weighing': 'weighing', 'midrange': 'mid range', 'blowng': 'blowing', 'yoursite': 'your site',
    'superbg': 'superb', 'intetnet': 'internet', 'besutiful': 'beautiful', 'suuuper': 'super', 'ate': 'ate', 'ceramicback': 'ceramic back', 'velvet': 'velvet', 'goog': 'good', 'doeswork': 'does work', 'interrface': 'interface',
    'spellings': 'spellings', 'competetion': 'competition', 'clarityis': 'clarity is', 'xclent': 'excellent', 'crome': 'chrome', 'sinply': 'simply', 'cermaic': 'ceramic', 'plz': 'please', 'compability': 'compatibility',
    'excellnt': 'excellent', 'iui': 'miui', 'ultraa': 'ultra', 'whatsoever': 'whatsoever', 'goodand': 'good and', 'gotcamera': 'got camera', 'ple': 'please', 'afortable': 'affordable', 'kns': 'kms', 'nicefeature': 'nice feature',
    'redemi': 'redmi', 'xxent': 'excellent', 'cuttrt': 'cutout', 'mi': 'mi', 'serires': 'series', 'whish': 'wish', 'dlexo': 'deluxe', 'cristal': 'crystal', 'makesense': 'make sense', 'gud': 'good', 'expellience': 'experience',
    'reflectiion': 'reflection', 'microphone': 'microphone', 'cameraquality': 'camera quality', 'awesomef': 'awesome', 'guddisplay': 'good display', 'frustrting': 'frustrating', 'vol': 'volume', 'cermaic': 'ceramic', 'clearence': 'clearance', 
    'snapdragon': 'snapdragon', 'ceramicback': 'ceramic back', 'cermaicback': 'ceramic back', 'snapdragon820': 'snapdragon 820', 'miui8': 'miui 8', 'snapdragon': 'snapdragon', 'snapdragon': 'snapdragon', 'snapdragon835': 'snapdragon 835', 'snapdragon820': 'snapdragon 820'
}
# Replace abbreviations in the Reviews column
for abbrev, full_form in abbreviation_dict.items():
    # Use word boundaries to ensure whole words are replaced
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + abbrev + r'\b', full_form, case=False, regex=True)

unwanted_words = [
    'euuuuuuuuuuuuuu', 'imei', 'xx', 'o', 'p', 'k', 'x', 'w', 'st', 'isbn', 'gb', 'min', 'mah', 'x x x', 'makhan',
    'bim', 'rd', 'r', 'n', 'nd', 'mm', 'fish', 'apple ka bar', 'mp', 'ppi', 'yrr', 'imei', 'k', 'science', 'x', 'nd',
    'rd', 'le', 'st', 'p', 'pm', 'f', 'tho', 'h', 'th', 'gn', 'xr', 'xl', 'am', 'tg', 'p', 'z', 'ce', 'ip', 'lt', 'td',
    'gt', 'lea', 'la', 'der', 'ir', 'j', 'sp', 'th', 'v', 'cg', 'wee', 'seg', 'g', 'pro', 'x', 'p', 'e', 'opt', 'nfc',
    'tm', 'ir', 'xnd', 'ffd', 'htc', 'cal', 'pm', 'ordo', 'gh', 'rn', 'mia', 'ip', 'sd', 'oct', 'core', 'expos', 'rd',
    'ip', 'pe', 'amp', 'paisa bassol', 'pc', 'al', 'zindabad', 'dnd', 'rsk', 'g', 'ooooooo', 'mmmmmmm', 'ggggggg', 'vfd',
    'havoc', 'ah', 'hi', 'hai', 'swimming', 'gop', 'ji', 'lajawab', 'asap loose', 'ie', 'h ago', 'madathukulam', 'mo', 
    'fea', 'l', 'ex', 'qu', 'Lotus', 'voodoo', 'ko', 'ont', 'maa', 'ag', 'ne', 'quot', 'sakuntala', 'rayagada bissamcuttack',
    'gimmick', 'thi', 'str', 'fatafati', 'mast', 'garcia jharkhand', 'sa', 'isvudn', 'x', 'sg', 'hijab', 'tbh', 'wars', 
    'nts', 'huawei', 'keirin', 'ofc', 'pg', 'sec', 'jaar', 'hai ye', 'th', 'ft', 'emu', 'gpu', 'fr', 'nit', 'eis', 'oo',
    'hh', 'ly', 'fei', 'q', 'c', 'sw', 'kd', 'ofc', 'bl', 'lol', 'et', 'rgh', 'extremewwe', 'dts', 'iu', 'vr', 'Soo', 
    'al', 'sm', 'rsk', 'eta', 'gh', 'nu', 'ota', 'fp'
]
# Remove unwanted words
for word in unwanted_words:
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + word + r'\b', '', case=False, regex=True)

# Save the updated DataFrame to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\motorola_reviews_final.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaned and saved successfully.")
# Out:
# Data cleaned and saved successfully.

# %%
import pandas as pd
# File path — update this to your file location
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_autocorrected.csv"

# Load the dataset
df = pd.read_csv(file_path)

# Dictionary of replacements
replacements = {
    'moto': 'motorola',
    'lg': 'life good',
    'cheerzzz': 'cheers',
    'plz': 'please',
    'mei': 'me',
    'worthy': 'worth',
    'gente': 'generation',
    'amd': 'and',
    'lte': 'light',
    'mid': 'middle',
    'awestruck': 'awesome struck',
    'abt': 'about',
    'tat': 'that',
    'dis': 'this',
    'v': 'we',
    'r': 'are',
    'exppos': 'exynos',
    'ill': 'i will',
    'ad': 'advertisement',
    'realm': 'realme',
    'sd': 'snapdragon',
    'bickering': 'flickering',
    'ex': 'example',
    'lcd': 'liquid crystal display',
    'fyi': 'for your information',
    'hd': 'high definition',
    'mio': 'mimo',
    'even tho': 'even though',
    'wowwwwww': 'wow',
    'redmipocohonor': 'redmi poco honor',
    'epxiernce': 'experience',
    'opt': 'option',
    'jan': 'january',
    'oct': 'october',
    'phonemes': 'phone',
    'portthats': 'port thats',
    'battery profane': 'battery performance',
    'ram': 'random access memory',
    'rom': 'read only memory',
    'hasn': 'has not',
    'spec': 'specification',
    'nsa': 'non standalone',
    'sa': 'signal antenna',
    'god': 'good',
    'camarabut': 'camera but',
    'awsmrest': 'awesome rest',
    'surfing': 'suffering',
    'androidmoto': 'android motorola',
    'topnotchperformance': 'top notch performance',
    'tommoro': 'tomorrow',
    'his friend': 'after few',
    'avg': 'average'
}

# Create a new column for cleaned reviews
df['Cleaned_Review'] = df['Autocorrected_Review']

# Apply replacements
for key, value in replacements.items():
    df['Cleaned_Review'] = df['Cleaned_Review'].str.replace(key, value, case=False, regex=True)

# Save the cleaned data
output_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_cleaned.csv"
df.to_csv(output_path, index=False)

print("✅ Text replacement completed successfully!")
print(f"File saved to: {output_path}")
# Out:
# ✅ Text replacement completed successfully!
# File saved to: C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_cleaned.csv

# %%
'x','p','e','opt','nfc','tm','ir','xnd','ffd','htc','cal','pm','ordo','gh','rn','mia','ip','sd','oct','core','expos','rd','ip','pe','amp','paisa bassol','pc','al','zindabad','dnd','rsk','g','ooooooo',
'mmmmmmm','ggggggg','vfd','havoc','ah','hi','hai','swimming','gop','ji','lajawab','asap loose','ie','h ago'
# Out:
# ('mmmmmmm',
#  'ggggggg',
#  'vfd',
#  'havoc',
#  'ah',
#  'hi',
#  'hai',
#  'swimming',
#  'gop',
#  'ji',
#  'lajawab',
#  'asap loose',
#  'ie',
#  'h ago')

# %%
replacements = {
    'moto': 'motorola',
    'lg': 'life good',
    'cheerzzz': 'cheers',
    'plz': 'please',
    'mei': 'me',
    'worthy': 'worth',
    'gente': 'generation',
    'amd': 'and',
    'lte': 'light',
    'mid': 'middle',
    'awestruck': 'awesome struck',
    'abt': 'about',
    'tat': 'that',
    'dis': 'this',
    'v': 'we',
    'r': 'are',
    'exppos': 'exynos',
    'ill': 'i will',
    'ad': 'advertisement',
    'realm': 'realme',
    'sd': 'snapdragon',
    'bickering': 'flickering',
    'ex': 'example',
    'lcd': 'liquid crystal display',
    'fyi': 'for your information',
    'hd': 'high definition',
    'mio': 'mimo',
    'even tho': 'even though',
    'wowwwwww': 'wow',
    'redmipocohonor': 'redmi poco honor',
    'epxiernce': 'experience',
    'opt': 'option',
    'jan': 'january',
    'oct': 'october',
    'phonemes': 'phone',
    'portthats': 'port thats',
    'battery profane': 'battery performance',
    'ram': 'random access memory',
    'rom': 'read only memory',
    'hasn': 'has not',
    'spec': 'specification',
    'nsa': 'non standalone',
    'sa': 'signal antenna',
    'god': 'good',
    'camarabut': 'camera but',
    'awsmrest': 'awesome rest',
    'surfing': 'suffering',
    'androidmoto': 'android motorola',
    'topnotchperformance': 'top notch performance',
    'tommoro': 'tomorrow',
    'his friend': 'after few',
    'avg': 'average',
    'knot': 'okay not',
    'mod': 'mode',
    'pho': 'phone',
    'phine': 'phone',
    'west': 'waste',
    'dayyyyyyyy': 'day',
    'parfomes': 'performance',
    'imp': 'important',
    'swimmer': 'shimmery',
    'gam': 'game',
    'goodcamra': 'good camera',
    'performancedont': 'performance do not',
    'mobileoppof': 'mobile oppo',
    'colitis': 'quality',
    'priformence': 'performance',
    'ny': 'nice',
    'goodmobail': 'good mobile',
    'product…': 'product',
    'performancegoo': 'performance',
    'superrrrr': 'super',
    'coma': 'come',
    'ju': 'just',
    'gotoofficewithstyle': 'go to office with style',
    'supervooc': 'super',
    'feb': 'february',
    'pais': 'money',
    'lightning': 'lightening',
    'lestvice': 'quality best',
    'fischer': 'feature',
    'slick': 'slim'
}

# %%
# Dictionary of replacements
replacements = {
    'knot': 'okay not',
    'mod': 'mode',
    'pho': 'phone',
    'phine': 'phone',
    'west': 'waste',
    'dayyyyyyyy': 'day',
    'parfomes': 'performance',
    'imp': 'important',
    'swimmer': 'shimmery',
    'gam': 'game',
    'goodcamra': 'good camera',
    'spec': 'specification',
    'performancedont': 'performance do not',
    'mobileoppof': 'mobile oppo',
    'colitis': 'quality',
    'priformence': 'performance',
    'ny': 'nice',
    'goodmobail': 'good mobile',
    'product…': 'product',
    'performancegoo': 'performance',
    'superrrrr': 'super',
    'coma': 'come',
    'ju': 'just',
    'gotoofficewithstyle': 'go to office with style',
    'supervooc': 'super',
    'feb': 'february',
    'pais': 'money',
    'lightning': 'lightening',
    'lestvice': 'quality best',
    'fischer': 'feature',
    'slick': 'slim'
}

# List of words to remove
remove_words = [
    'madathukulam', 'mo', 'fea', 'l', 'ex', 'qu', 'Lotus', 'voodoo', 'ko', 'ont', 'maa', 'ag',
    'ne', 'quot', 'sakuntala', 'rayagada bissamcuttack', 'gimmick', 'thi', 'str', 'fatafati',
    'mast', 'garcia jharkhand', 'sa', 'isvudn'
]

# %% [markdown]
# **GOOGLE**

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import emoji

# Load the data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\google_merged.csv"
df = pd.read_csv(file_path)

# Handle missing values
# Drop rows where the Reviews text is missing
df.dropna(subset=['Review'], inplace=True)

# Ensure all entries in the Reviews column are strings
df['Review'] = df['Review'].astype(str)

# Remove emojis using the emoji library
def remove_emojis(text):
    return emoji.replace_emoji(text, replace='')

# Remove special characters and digits
def remove_special_characters(text):
    return re.sub('[^a-zA-Z\s]', '', text)

# Normalize the text
def normalize_text(text):
    text = text.lower()  # Convert to lowercase
    text = remove_emojis(text)
    text = remove_special_characters(text)
    text = re.sub('\s+', ' ', text)  # Remove extra spaces
    return text

# Apply normalization
df['Cleaned_Review'] = df['Review'].apply(normalize_text)

# Remove stopwords
stop_words = set(stopwords.words('english'))
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# Apply lemmatization
lemmatizer = WordNetLemmatizer()
df['Cleaned_Review'] = df['Cleaned_Review'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\google_reviews_cleaned.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning completed and saved to", output_file_path)
# Out:
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# <>:25: SyntaxWarning: invalid escape sequence '\s'
# <>:32: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_17972\2686502659.py:25: SyntaxWarning: invalid escape sequence '\s'
#   return re.sub('[^a-zA-Z\s]', '', text)
# C:\Users\HP\AppData\Local\Temp\ipykernel_17972\2686502659.py:32: SyntaxWarning: invalid escape sequence '\s'
#   text = re.sub('\s+', ' ', text)  # Remove extra spaces
# Data cleaning completed and saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\google_reviews_cleaned.csv

# %%
import pandas as pd
from autocorrect import Speller

# Load the data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\google_reviews_cleaned.csv"
df = pd.read_csv(file_path)# Apply autocorrect using autocorrect library
spell = Speller(lang='en')

def correct_spelling(text):
    return ' '.join([spell(word) for word in text.split()])

df['Autocorrected_Review'] = df['Cleaned_Review'].apply(correct_spelling)

# Save the cleaned data to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\google_reviews_autocorrected.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaning and spell correction completed and saved to", output_file_path)
# Out:
# Data cleaning and spell correction completed and saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\google_reviews_autocorrected.csv

# %%
import pandas as pd
import re

# Load the cleaned data
file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\google_reviews_autocorrected.csv"
df = pd.read_csv(file_path)

# Create a new column 'Reviews' based on 'Autocorrected_Reviews'
df['Reviews'] = df['Autocorrected_Review']

# Dictionary of specific abbreviations and their corrections
abbreviation_dict = {
    'camara': 'camera', 'fps': 'frames per second', 'oplus': 'oneplus', 'sd gen': 'snapdragon generation', 'superb': 'super',
    'professor': 'processor', 'sound college': 'sound quality', 'dam': 'damn', 'opp': 'oppo', 'aws': 'awesome',
    'vry gd': 'very good', 'supppoppp': 'super', 'prosesar': 'processor', 'approx hr sot': 'approximately hour screen on time',
    'u': 'you', 'hr': 'hour', 'prosper': 'processor', 'usa': 'usage', 'good pro': 'good product', 'gd': 'good',
    'nice prod': 'nice product', 'p': 'performance', 'ui': 'user interface', 'day us': 'day usage', 'prosesar': 'processor',
    'flipcart': 'flipkart', 'battery beast': 'battery best', 'ease': 'easy', 'pub': 'pubg', 'osm': 'awesome',
    'worth karma worthuuu': 'worth the money', 'ois': 'optical image stabilization', 'aim happy': 'i am happy',
    'pub cod': 'pubg, call of duty', 'hz': 'hertz', 'degree census': 'degree celsius', 'nd': 'and',
    'hit issue': 'heating issue', 'ai': 'artificial intelligence', 'wil': 'will', 'tax': 'thanks', 'anthem': 'item',
    'mint camera': 'main camera', 'heat throttle': 'heating and throttling', 'ill update': 'i will update',
    'phone devils aswoome': 'phone device is awesome', 'hdr': 'high dynamic range', 'fo': 'for',
    'op ti really': 'oneplus really', 'one plus ph': 'oneplus phone', 'spr': 'super', 'apprehension': 'appreciation',
    'max': 'maximum', 'oxygen o': 'oxygen os', 'kinda': 'kind of', 'medio': 'mediocre', 'btw': 'by the way', 'assam': 'awesome',
    'ph': 'phone', 'bos': 'range boost', 'beast': 'best', 'dlr': 'dslr', 'batter': 'better', 'cod': 'call of duty', 'nyc': 'nice',
    'unvilevebale item': 'unbelievable item', 'supper': 'super', 'op': 'oneplus', 'assume': 'awesome',
    'osm dolly atoms': 'awesome dolby atmos', 'mic failed': 'microphone failed', 'premium paper': 'premium feel', 'ver': 'very',
    'gonna': 'going to', 'pub': 'pubg', 'gun': 'good', 'jus': 'just', 'ive': 'i have', 'extent': 'excellent', 'nice hoon': 'nice phone',
    'gr': 'great', 'math': 'match', 'bt': 'but', 'ok':'okay', 'costa': 'costar', 'beast': 'best', 'hr': 'hour', 'sha': 'should',
    'wk': 'week', "hadnt": "had not", "im": "i am", "havent": "have not", "hasnt": "has not", 'u': "you", 'r': "are",
    "ui": "user interface", "doesnt": "does not", 'rambling': "rumbling", "io": "iphone operating system", 
    "sot": "special operation team", "le": "less", "fhd": "full high definition", "dont": "do not",
    "cam": "camera", "came": "camera", "avg": "average", "yea": "yeah", "lil": "little", 
    "costlier": "more expensive", "it's": "it is", "very": "very", "n": "and", "cant": "cannot", "dis": "this", "v": "we", 
    "hdr": 'high dynamic range', "didnt": "did not", "ive": "i have", "bezel": "bezel", "ur": "your", "wont": 'will not', 
    "hd": 'high definition', 'cleanui': "clean user interface", "tatics": "haptics", "sd": "secure digital", "gen": "generation", 
    "usp": 'unique selling proposition', 'degc': "degree celsius", "tatic": "haptic", "unbuilt": "inbuilt", 'xiomi': "xiaomi",
    'regreating': "regretting", 'fyi': "for your information", 'issuehrs': "issue hours", 'doomed': "zoomed",
    'ois': "optical image stabilization", 'theyll': "they will", 'ig': "instagram", 'bbd': "bigger better deal", 'cemra': "camera", 
    'fastly': "fast", "optimise": 'optimize', 'osum': 'awesome', 'vi': "vodafone", 'upi': "unified payments interface",
    'eyeturner': "eye turner", 'banger': "banger", 're': "resolution", 'goddamn': "goddamn", 'aint': "am not", 'plesently': "pleasantly", 
    'thik': "think", "tooo": "too", "uisvery": 'user interface very', 'gif': "graphics interchange format", 'siz': "six", 
    'costlier': "costlier", 'iphones': "iphone", 'youre': 'you are', 'doubtbut': "doubt but", 'phome': "phone", 'red': "redmi", 
    'okif': "okay if", 'pic': "picture", 'smatter': 'smarter', 'membrane': "ambrane", "holdnew": 'hold new', 'swine': "swipe", 
    'inshot': "inshot", 'pixelated': "pixel related", 'cameraai': "camera artificial intelligence", 'oppos': 'oppo', 'amaze': "amazing", 
    'daytoday': "day to day", 'offmy': "off my", 'laggy': "lag", 'victus': "victus", 'slowlike': "slow like",
    'wholeday': "full day", 'commendable': "recommendable", 'baku': "vaku", 
    'beat': "best", 'surfed': "suffered", 'bgmi': "battle ground mobile india", 'isnt': "is not", 
    'flickering': "flickering", 'least': "at least", 'doun': "down", 'thats': "that is", 'ill': "i will", 'bout': "about", 
    'butter': "better", 'emi': "equated monthly installment", 'prefect': "perfect", 'ketone': "keyone", 
    'ie': "in other words", 'cuz': "because", "youve": "you have", 'ott': "over the top", 
    'oct': "october", 'ois': "optical image stabilization", 'ip': "iphone", 'nowhope': "now hope", 'red': "redmi",
    "eraserunblur": "eraser focus", "wifi": "wireless fidelity", 'ok': "okay", 'hiccup': "hiccup",
    'janso': "january so", 'mahmaybe': "milliampere hour may be", 'lovable': "lovable", 'etc': "et cetera", "karma": "varma",
    'dayyyyyyyy': "day", 'pic': "picture", 'camra': "camera", 'Vry': "very", 'easilllyy': "easily",
    'came': "camera", 'mob': "mobile", 'flipcard': "flipkart", 'Kkk': "okay", 'swimmer': 'shimmery', 'supeeeeer': 'super', 'ur': 'your', 'nais': 'nice', 'descent': 'decent', 'se user': 'super', 'nris': 'nice',
    'suuuuuuuuuuuuuuper': 'super', 'project': 'product', 'xtra': 'extra', 'userniterface': 'user interface', 'prossecer': 'processor', 'amazingest': 'amazing',
    'col': 'color', 'superbbbbb': 'superb', 'goog': 'good', 'censor': 'sensor', 'ram': 'ram', 'wwwhhhoooooooo': 'who', 'pictre': 'picture', 'comera': 'camera', 'fa': 'for',
    'truely': 'truly', 'fonnne': 'phone', 'excellant': 'excellent', 'totallly': 'totally', 'ceramicback': 'ceramic back', 'internat': 'internet', 'iui': 'miui', 'camaera': 'camera', 'supper': 'super',
    'exllent': 'excellent', 'magnafiqui': 'magnificent', 'affecfordble': 'affordable', 'smmmmooooothhhhhh': 'smooth', 'veryg': 'very good', 'camaera': 'camera',
    'ar': 'are', 'eet': 'get', 'june': 'june', 'ster': 'star', 'osam': 'awesome', 'gona': 'gonna', 'suchh': 'such', 'amoled': 'amoled', 'fon': 'phone', 'ram': 'ram', 'exp': 'expensive',
    'xclent': 'excellent', 'ans': 'and', 'shotcut': 'shortcut', 'expoerience': 'experience', 'bgmi': 'battle grounds mobile india', 'anr': 'and', 'whao': 'wow', 'awesomeeee': 'awesome', 'blurr': 'blur',
    'definately': 'definitely', 'suuuuper': 'super', 'nize': 'nice', 'phobe': 'phone', 'thanksflipcart': 'thanks flipkart', 'mimax': 'mi max', 'picure': 'picture', 'blutooth': 'bluetooth', 'qhy': 'why',
    'user interfce': 'user interface', 'beasutiful': 'beautiful', 'smother': 'smoother', 'gooddd': 'good', 'ramgood': 'ram good', 'smother': 'smoother', 'suggestable': 'suggestible', 'gamesro': 'games to',
    'playbles': 'playable', 'fes': 'fest', 'crystalclear': 'crystal clear', 'ph': 'phone', 'frimeware': 'firmware', 'dowload': 'download', 'camara': 'camera', 'gud': 'good', 'jio': 'jio', 'againflipkart': 'again flipkart',
    'imposible': 'impossible', 'comfortbale': 'comfortable', 'whith': 'with', 'chages': 'changes', 'consiser': 'consider', 'heatsup': 'heats up', 'grt': 'great', 'fringerprint': 'fingerprint', 'detailingg': 'detailing',
    'gud': 'good', 'hz': 'hertz', 'nd': 'and', 'soundcollage': 'sound quality', 'wi': 'with', 'appreciateble': 'appreciable', 'phn': 'phone', 'mu': 'music', 'preforance': 'performance', 'veryyy': 'very',
    'ceramicback': 'ceramic back', 'ceraicback': 'ceramic back', 'battrey': 'battery', 'hollywow': 'hollywood', 'expirence': 'experience', 'niceui': 'nice user interface', 'terriffic': 'terrific', 'varien': 'variant',
    'xcellent': 'excellent', 'sorring': 'scoring', 'comfrtable': 'comfortable', 'mics': 'microphones', 'cds': 'cd', 'whot': 'what', 'mindbloing': 'mind blowing', 'gamesome': 'games on', 'fluently': 'fluent',
    'dat': 'that', 'amasing': 'amazing', 'superrr': 'super', 'osm': 'awesome', 'hreat': 'great', 'costefficeint': 'cost efficient', 'bhaskar': 'bhaskaran', 'heatingproblem': 'heating problem',
    'miracast': 'miracast', 'definately': 'definitely', 'wo': 'would', 'thsnks': 'thanks', 'whywhy': 'why why', 'cam': 'camera', 'gaurantee': 'guarantee', 'crazychaging': 'crazy charging',
    'interfece': 'interface', 'excellant': 'excellent', 'intenation': 'internet', 'bettry': 'battery', 'exellent': 'excellent', 'lockscreen': 'lock screen', 'tap': 'tap', 'eb': 'is',
    'cam': 'camera', 'exellent': 'excellent', 'pros': 'pros', 'cus': 'because', 'definatly': 'definitely', 'microphoneon': 'microphone on', 'renaining': 'remaining', 'nxet': 'next',
    'switcher': 'switcher', 'yooo': 'yo', 'exlent': 'excellent', 'vol': 'volume', 'magic': 'magic', 'beacuse': 'because', 'ven': 'even', 'expence': 'expense', 'pones': 'phones',
    'pu': 'pubg', 'exlent': 'excellent', 'bgmi': 'battle ground mobile india', 'athir': 'arshad', 'ramaining': 'remaining', 'docing': 'docking', 'batterylife': 'battery life', 'batt': 'battery', 
    'cas': 'case', 'proble': 'problem', 'sa': 'sa', 'lense': 'lens', 'cameraof': 'camera of', 'parformance': 'performance', 'whatsapp': 'whatsapp', 'camra': 'camera', 'amoleddisplay': 'amoled display',
    'hugh': 'high', 'exellent': 'excellent', 'phon': 'phone', 'boaring': 'boring', 'sync': 'sync', 'flipkart': 'flipkart', 'tp': 'to', 'displayflipkart': 'display flipkart', 'flipcart': 'flipkart',
    'complain': 'complain', 'sdgen': 'snapdragon generation', 'comerabgmi': 'camera battle ground mobile india', 'doint': 'do not', 'iys': 'it is', 'superp': 'super', 'expeeience': 'experience', 'loook': 'look',
    'couple': 'couple', 'phoneflipkart': 'phone flipkart', 'got': 'got', 'consisency': 'consistency', 'dispkay': 'display', 'proc': 'processor', 'gud': 'good', 'clarityclearity': 'clarity', 'octo': 'octa',
    'excessive': 'excessive', 'goodem': 'good em', 'snapdragon': 'snapdragon', 'camara': 'camera', 'sper': 'super', 'rebooting': 'rebooting', 'accessorry': 'accessory', 'usr': 'user', 'dispkay': 'display',
    'pictureclarity': 'picture clarity', 'dispkayclarity': 'display clarity', 'extremely': 'extremely', 'awsome': 'awesome', 'goodcamera': 'good camera', 'goodclatrity': 'good clarity', 'miui': 'miui',
    'clearn': 'clear', 'cllick': 'click', 'reseting': 'resetting', 'psl': 'psl', 'edxtra': 'extra', 'redmy': 'redmi', 'gamy': 'game', 'biometrics': 'biometrics', 'noney': 'money', 'lenovo': 'lenovo',
    'possessing': 'processing', 'ossam': 'awesome', 'tis': 'this', 'surport': 'support', 'awsom': 'awesome', 'supere': 'super', 'serviceflipkart': 'service flipkart', 'awesomeas': 'awesome', 'greate': 'great',
    'mobs': 'mobile', 'sept': 'september', 'its': 'its', 'wasawsm': 'was awesome', 'flipkartgood': 'flipkart good', 'easeofuse': 'ease of use', 'mi': 'mi', 'perfectperfect': 'perfect', 'ohow': 'oh how',
    'dosn': 'does', 'okkay': 'okay', 'awdome': 'awesome', 'des': 'des', 'awesomefeature': 'awesome feature', 'circa': 'circa', 'gud': 'good', 'backca': 'back cover', 'yhe': 'the', 'niceproduct': 'nice product',
    'me':'mi', 'awesomegod': 'awesome', 'tricking': 'tricking', 'allure': 'allure', 'mia1': 'mi a1', 'backpanel': 'back panel', 'microwave': 'microphone', 'fri': 'friend', 'frusterating': 'frustrating','moto':'motorola',
    'rs': 'rs', 'chat': 'chat', 'saiz': 'size', 'ram': 'ram', 'workswll': 'works well', 'mid': 'mi', 'ph': 'phone', 'flpkrt': 'flipkart', 'blowming': 'blowing', 'complaince': 'complain', 'ar': 'are', 'phn': 'phone',
    'usb': 'usb', 'coverback': 'cover back', 'awesomecamera': 'awesome camera', 'osame': 'awesome', 'bat': 'battery', 'weighing': 'weighing', 'midrange': 'mid range', 'blowng': 'blowing', 'yoursite': 'your site',
    'superbg': 'superb', 'intetnet': 'internet', 'besutiful': 'beautiful', 'suuuper': 'super', 'ate': 'ate', 'ceramicback': 'ceramic back', 'velvet': 'velvet', 'goog': 'good', 'doeswork': 'does work', 'interrface': 'interface',
    'spellings': 'spellings', 'competetion': 'competition', 'clarityis': 'clarity is', 'xclent': 'excellent', 'crome': 'chrome', 'sinply': 'simply', 'cermaic': 'ceramic', 'plz': 'please', 'compability': 'compatibility',
    'excellnt': 'excellent', 'iui': 'miui', 'ultraa': 'ultra', 'whatsoever': 'whatsoever', 'goodand': 'good and', 'gotcamera': 'got camera', 'ple': 'please', 'afortable': 'affordable', 'kns': 'kms', 'nicefeature': 'nice feature',
    'redemi': 'redmi', 'xxent': 'excellent', 'cuttrt': 'cutout', 'mi': 'mi', 'serires': 'series', 'whish': 'wish', 'dlexo': 'deluxe', 'cristal': 'crystal', 'makesense': 'make sense', 'gud': 'good', 'expellience': 'experience',
    'reflectiion': 'reflection', 'microphone': 'microphone', 'cameraquality': 'camera quality', 'awesomef': 'awesome', 'guddisplay': 'good display', 'frustrting': 'frustrating', 'vol': 'volume', 'cermaic': 'ceramic', 'clearence': 'clearance', 
    'snapdragon': 'snapdragon', 'ceramicback': 'ceramic back', 'cermaicback': 'ceramic back', 'snapdragon820': 'snapdragon 820', 'miui8': 'miui 8', 'snapdragon': 'snapdragon', 'snapdragon': 'snapdragon', 'snapdragon835': 'snapdragon 835', 'snapdragon820': 'snapdragon 820'
}
# Replace abbreviations in the Reviews column
for abbrev, full_form in abbreviation_dict.items():
    # Use word boundaries to ensure whole words are replaced
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + abbrev + r'\b', full_form, case=False, regex=True)

unwanted_words = [
    'euuuuuuuuuuuuuu', 'imei', 'xx', 'o', 'p', 'k', 'x', 'w', 'st', 'isbn', 'gb', 'min', 'mah', 'x x x', 'makhan',
    'bim', 'rd', 'r', 'n', 'nd', 'mm', 'fish', 'apple ka bar', 'mp', 'ppi', 'yrr', 'imei', 'k', 'science', 'x', 'nd',
    'rd', 'le', 'st', 'p', 'pm', 'f', 'tho', 'h', 'th', 'gn', 'xr', 'xl', 'am', 'tg', 'p', 'z', 'ce', 'ip', 'lt', 'td',
    'gt', 'lea', 'la', 'der', 'ir', 'j', 'sp', 'th', 'v', 'cg', 'wee', 'seg', 'g', 'pro', 'x', 'p', 'e', 'opt', 'nfc',
    'tm', 'ir', 'xnd', 'ffd', 'htc', 'cal', 'pm', 'ordo', 'gh', 'rn', 'mia', 'ip', 'sd', 'oct', 'core', 'expos', 'rd',
    'ip', 'pe', 'amp', 'paisa bassol', 'pc', 'al', 'zindabad', 'dnd', 'rsk', 'g', 'ooooooo', 'mmmmmmm', 'ggggggg', 'vfd',
    'havoc', 'ah', 'hi', 'hai', 'swimming', 'gop', 'ji', 'lajawab', 'asap loose', 'ie', 'h ago', 'madathukulam', 'mo', 
    'fea', 'l', 'ex', 'qu', 'Lotus', 'voodoo', 'ko', 'ont', 'maa', 'ag', 'ne', 'quot', 'sakuntala', 'rayagada bissamcuttack',
    'gimmick', 'thi', 'str', 'fatafati', 'mast', 'garcia jharkhand', 'sa', 'isvudn', 'x', 'sg', 'hijab', 'tbh', 'wars', 
    'nts', 'huawei', 'keirin', 'ofc', 'pg', 'sec', 'jaar', 'hai ye', 'th', 'ft', 'emu', 'gpu', 'fr', 'nit', 'eis', 'oo',
    'hh', 'ly', 'fei', 'q', 'c', 'sw', 'kd', 'ofc', 'bl', 'lol', 'et', 'rgh', 'extremewwe', 'dts', 'iu', 'vr', 'Soo', 
    'al', 'sm', 'rsk', 'eta', 'gh', 'nu', 'ota', 'fp'
]
# Remove unwanted words
for word in unwanted_words:
    df['Reviews'] = df['Reviews'].str.replace(r'\b' + word + r'\b', '', case=False, regex=True)

# Save the updated DataFrame to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\google_reviews_final.csv"
df.to_csv(output_file_path, index=False)

print("Data cleaned and saved successfully.")
# Out:
# Data cleaned and saved successfully.

# %%
import pandas as pd
import glob

# List of file paths to combine
file_paths = [
    r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\motorola_reviews_final.csv",
    r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oneplus_reviews_final.csv",
    r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Honor_reviews_final.csv",
    r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\google_reviews_final.csv",
    r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\oppo_reviews_final.csv",
]

# Initialize an empty list to hold DataFrames
dfs = []

# Read each file and append the DataFrame to the list
for file_path in file_paths:
    df = pd.read_csv(file_path)
    dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# Drop rows with missing values
combined_df.dropna(inplace=True)

# Drop specified columns
columns_to_drop = ['Autocorrected_Review', 'Product_Link', 'Product_Price', 'Cleaned_Review', 'Review']
combined_df.drop(columns=columns_to_drop, inplace=True, errors='ignore')

# Rename the specified columns
columns_to_rename = {'Rating': 'Ratings'}
combined_df.rename(columns=columns_to_rename, inplace=True)

# Count the number of duplicate rows
duplicate_count = combined_df.duplicated(keep=False).sum()
print(f"Number of duplicate rows: {duplicate_count}")

# Drop duplicate rows
combined_df.drop_duplicates(inplace=True)

# Save the combined DataFrame to a new CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_Products_reviews.csv"
combined_df.to_csv(output_file_path, index=False)

print("Combined DataFrame created successfully and saved.")
# Out:
# Number of duplicate rows: 3881
# Combined DataFrame created successfully and saved.

# %%
df = pd.read_csv(r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_Products_reviews.csv")
df
# Out:
#                                             Product_Name  Ratings  \
# 0      MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream...      4.5
# 1      MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream...      5.0
# 2      MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream...      5.0
# 3      MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream...      5.0
# 4      MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream...      4.0
# ...                                                  ...      ...
# 13976             OPPO F25 Pro 5G (Coral Purple, 128 GB)      5.0
# 13977             OPPO F25 Pro 5G (Coral Purple, 128 GB)      5.0
# 13978             OPPO F25 Pro 5G (Coral Purple, 128 GB)      5.0
# 13979             OPPO F25 Pro 5G (Coral Purple, 128 GB)      5.0
# 13980             OPPO F25 Pro 5G (Coral Purple, 128 GB)      5.0
#
#                                                  Reviews
# 0                                           nice product
# 1      everything good motorola also launch mobile ra...
# 2                                     good image quality
# 3      phone good less one gallery app phone provide ...
# 4                                  super fully satisfied
# ...                                                  ...
# 13976                                          excellent
# 13977                         nice product  overall good
# 13978                                        good mobile
# 13979                                       good product
# 13980                                    everything well
#
# [13981 rows x 3 columns]

# %%
df['Product_ID'] = pd.factorize(df['Product_Name'])[0] + 1

# %%
import pandas as pd
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk

# ✅ Step 1: Download VADER lexicon (run this once)
nltk.download('vader_lexicon')

# ✅ Step 2: Load your DataFrame from the CSV file
input_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_Products_reviews.csv"
df = pd.read_csv(input_file_path)

# Creating a Product_ID column by factorizing Product_Name
df['Product_ID'] = pd.factorize(df['Product_Name'])[0] + 1

# ✅ Step 3: Initialize VADER Sentiment Analyzer
sia = SentimentIntensityAnalyzer()

# ✅ Step 4: Define a function to get sentiment scores
def get_sentiment(review):
    if isinstance(review, str):  # handle NaN or non-string values
        sentiment = sia.polarity_scores(review)
        return sentiment['compound']  # compound score ranges from -1 to 1
    return 0  # neutral if review missing

# ✅ Step 5: Apply the function to the Review column
df['Sentiment_Score'] = df['Reviews'].apply(get_sentiment)

# ✅ Step 6: Classify sentiment as Positive, Negative, or Neutral
df['Sentiment'] = df['Sentiment_Score'].apply(
    lambda score: 'Positive' if score > 0.05 else ('Negative' if score < -0.05 else 'Neutral')
)

# ✅ Step 7: Save the DataFrame to a CSV file
output_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_Products_reviews_with_sentiment.csv"
df.to_csv(output_file_path, index=False)

print(f"✅ Sentiment analysis results saved to: {output_file_path}")
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# ✅ Sentiment analysis results saved to: C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_Products_reviews_with_sentiment.csv

# %%
df = pd.read_csv(r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_Products_reviews_with_sentiment.csv")

# %%
df[df['Sentiment'] == 'Negative']
# Out:
#                                             Product_Name  Ratings  \
# 36     MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream...      5.0
# 38     MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream...      5.0
# 44     MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream...      5.0
# 64            Motorola Edge 50 Fusion (Hot Pink, 256 GB)      5.0
# 114        Motorola Edge 50 Fusion (Forest Blue, 256 GB)      5.0
# ...                                                  ...      ...
# 13891             OPPO F25 Pro 5G (Coral Purple, 128 GB)      5.0
# 13898             OPPO F25 Pro 5G (Coral Purple, 128 GB)      4.3
# 13917             OPPO F25 Pro 5G (Coral Purple, 128 GB)      4.0
# 13925             OPPO F25 Pro 5G (Coral Purple, 128 GB)      3.0
# 13975             OPPO F25 Pro 5G (Coral Purple, 128 GB)      4.0
#
#                                                  Reviews  Product_ID  \
# 36                                                   bad           1
# 38     software problem occasion switch automatically...           1
# 44     using month writing review stylish phone doubt...           1
# 64     phone best price range expected seen disadvant...           2
# 114    phone best price range expected seen disadvant...           3
# ...                                                  ...         ...
# 13891  first day use heating issue do not product cam...         188
# 13898                        disappointed camera battery         188
# 13917          selfie camera good bad picture night mode         188
# 13925  battery performance bad camera performance dis...         188
# 13975                                internet ic problem         188
#
#        Sentiment_Score Sentiment
# 36             -0.5423  Negative
# 38             -0.5873  Negative
# 44             -0.8481  Negative
# 64             -0.8118  Negative
# 114            -0.8118  Negative
# ...                ...       ...
# 13891          -0.4788  Negative
# 13898          -0.4767  Negative
# 13917          -0.1531  Negative
# 13925          -0.5423  Negative
# 13975          -0.4019  Negative
#
# [697 rows x 6 columns]

# %%
pd.set_option("display.max_rows", None)
pd.set_option("display.max_colwidth", None)

# %%
import pandas as pd

# Step 1: Load your DataFrame from the CSV file
input_file_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_Products_reviews_with_sentiment.csv"
df = pd.read_csv(input_file_path)

# Step 2: Aggregate average sentiment scores by Product_Name
product_recommendations = df.groupby('Product_Name').agg({
    'Product_ID': 'first',           # Get the first Product_ID for each product
    'Sentiment': 'first',            # Get the first Sentiment for each product
    'Sentiment_Score': 'mean',       # Average sentiment score
    'Ratings': 'mean',               # Average rating
    'Reviews': 'count'               # Count of reviews
}).reset_index()

# Step 3: Sort the products by average sentiment score
product_recommendations = product_recommendations.sort_values(by='Sentiment_Score', ascending=False)

# Step 4: Save the resulting DataFrame to a CSV file
output_path = r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_mobile_recommendation.csv"
product_recommendations.to_csv(output_path, index=False)

print(f"Product recommendations saved to {output_path}")
# Out:
# Product recommendations saved to C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_mobile_recommendation.csv

# %%
df = pd.read_csv(r"C:\Users\HP\OneDrive\Documents\Desktop\Flipkart_scapping\Flipkart_mobile_recommendation.csv")
df
# Out:
#                                                             Product_Name  \
# 0                                       Honor Holly (Black/White, 16 GB)
# 1                                               Honor 6X (Silver, 64 GB)
# 2                                                 Honor 6X (Grey, 64 GB)
# 3                                    Google Pixel 7 (Lemongrass, 128 GB)
# 4                                          Google Pixel 7 (Snow, 128 GB)
# 5                                      Google Pixel 7 (Obsidian, 128 GB)
# 6                                               Honor 6X (Silver, 32 GB)
# 7                                                 Honor 6X (Gold, 32 GB)
# 8                                                 Honor 6X (Grey, 32 GB)
# 9                                   Honor 8 Pro (Midnight Black, 128 GB)
# 10                                       Honor 8 Pro (Navy Blue, 128 GB)
# 11                         Motorola Edge 30 Fusion (Cosmic grey, 128 GB)
# 12                                  MOTOROLA g82 5G (White Lily, 128 GB)
# 13                                      Honor 9N (Midnight Black, 64 GB)
# 14                                       Honor 9N (Sapphire Blue, 64 GB)
# 15                                      Honor 9N (Sapphire Blue, 128 GB)
# 16                      Motorola Edge 30 Ultra (Starlight White, 128 GB)
# 17                   Motorola Edge 30 Ultra (Interstellar Black, 128 GB)
# 18                                         Honor 9i (Aurora Blue, 64 GB)
# 19                       MOTOROLA One Vision (Sapphire Gradient, 128 GB)
# 20                               Motorola g73 5G (Midnight Blue, 128 GB)
# 21                                Motorola g73 5G (Lucent White, 128 GB)
# 22                                                Honor 7A (Gold, 32 GB)
# 23                              Motorola G60 (Frosted Champagne, 128 GB)
# 24                                    Motorola G60 (Soft Silver, 128 GB)
# 25                                       Motorola G60 (Moonless, 128 GB)
# 26      Motorola Edge 50 Pro 5G with 68W Charger (Vanilla Cream, 256 GB)
# 27    Motorola Edge 50 Pro 5G with 68W Charger (Moonlight Pearl, 256 GB)
# 28       Motorola Edge 50 Pro 5G with 68W Charger (Black Beauty, 256 GB)
# 29      Motorola Edge 50 Pro 5G with 68W Charger (Luxe Lavender, 256 GB)
# 30                                Motorola Edge 30 (Meteor Grey, 128 GB)
# 31                           MOTOROLA Moto G 5G (Frosted Silver, 128 GB)
# 32                            MOTOROLA Moto G 5G (Volcanic Grey, 128 GB)
# 33                                       Google Pixel 7a (Coral, 128 GB)
# 34                                         Google Pixel 7a (Sea, 128 GB)
# 35                                        Google Pixel 7a (Snow, 128 GB)
# 36                                    Google Pixel 7a (Charcoal, 128 GB)
# 37     Motorola Edge 50 Pro 5G with 125W Charger (Vanilla Cream, 256 GB)
# 38        Motorola Edge 50 Pro 5G with 125W Charger (Caneel Bay, 256 GB)
# 39   Motorola Edge 50 Pro 5G with 125W Charger (Moonlight Pearl, 256 GB)
# 40     Motorola Edge 50 Pro 5G with 125W Charger (Luxe Lavender, 256 GB)
# 41      Motorola Edge 50 Pro 5G with 125W Charger (Black Beauty, 256 GB)
# 42                                Honor 200 5G (Moonlight White, 512 GB)
# 43                                          Honor 200 5G (Black, 512 GB)
# 44                               Motorola G62 5G (Midnight Gray, 128 GB)
# 45                                Motorola G62 5G (Frosted Blue, 128 GB)
# 46                                       Google Pixel 6a (Chalk, 128 GB)
# 47                               Motorola Edge 40 (Nebula Green, 256 GB)
# 48                              Motorola Edge 40 (Eclipse Black, 256 GB)
# 49                               Motorola Edge 40 (Viva Magenta, 256 GB)
# 50                                 Motorola Edge 40 (Lunar Blue, 256 GB)
# 51                           Motorola Edge 40 Neo (Soothing Sea, 256 GB)
# 52                           Motorola Edge 40 Neo (Black Beauty, 256 GB)
# 53                             Motorola Edge 40 Neo (Caneel Bay, 256 GB)
# 54                             Motorola Edge 40 Neo (Peach Fuzz, 256 GB)
# 55                                         Google Pixel 8a (Bay, 128 GB)
# 56                                   Google Pixel 8a (Porcelain, 128 GB)
# 57                                    Google Pixel 8a (Obsidian, 128 GB)
# 58                                        Google Pixel 8a (Aloe, 128 GB)
# 59                         Motorola Edge 50 Fusion (Forest Blue, 256 GB)
# 60                        Motorola Edge 50 Fusion (Forest Green, 256 GB)
# 61                            Motorola Edge 50 Fusion (Hot Pink, 256 GB)
# 62                    Motorola Edge 50 Fusion (Marshmallow Blue, 256 GB)
# 63                                       OPPO RENO 13 5G (White, 128 GB)
# 64                               OPPO RENO 13 5G (Luminous Blue, 128 GB)
# 65                      Motorola Edge 30 Ultra (Starlight White, 256 GB)
# 66                   Motorola Edge 30 Ultra (Interstellar Black, 256 GB)
# 67                                  Motorola g54 5G (Pearl Blue, 256 GB)
# 68                                  Motorola g54 5G (Mint Green, 256 GB)
# 69                               Motorola g54 5G (Midnight Blue, 256 GB)
# 70                             Motorola Edge 40 Neo (Peach Fuzz, 128 GB)
# 71                             Motorola Edge 40 Neo (Caneel Bay, 128 GB)
# 72                           Motorola Edge 40 Neo (Soothing Sea, 128 GB)
# 73                           Motorola Edge 40 Neo (Black Beauty, 128 GB)
# 74                                      Honor 9N (Midnight Black, 32 GB)
# 75                         MOTOROLA Edge 60 Pro (Pantone Shadow, 256 GB)
# 76                  MOTOROLA Edge 60 Pro (Pantone Dazzling Blue, 256 GB)
# 77                         MOTOROLA Edge 60 Pro (Pantone Walnut, 256 GB)
# 78                MOTOROLA Edge 60 Pro (Pantone Sparkling Grape, 256 GB)
# 79                              OnePlus 11R 5G (Galactic Silver, 128 GB)
# 80                                  OnePlus 11R 5G (Sonic Black, 128 GB)
# 81                   MOTOROLA Edge 60 5G (PANTONE Gibraltar Sea, 256 GB)
# 82                        MOTOROLA Edge 60 5G (PANTONE Shamrock, 256 GB)
# 83                                 OPPO Reno10 5G (Silvery Grey, 256 GB)
# 84                                           Honor 90 5G (Green, 512 GB)
# 85                                  Honor 90 5G (Midnight Black, 512 GB)
# 86                                  Honor 90 5G (Diamond Silver, 256 GB)
# 87                                   Honor 90 5G (Emerald Green, 256 GB)
# 88               MOTOROLA Edge 60 Stylus (PANTONE Gibraltar Sea, 256 GB)
# 89                                Motorola g84 5G (Viva Magenta, 256 GB)
# 90                               Motorola g84 5G (Midnight Blue, 256 GB)
# 91                            Motorola g84 5G (Marshmallow Blue, 256 GB)
# 92                              OnePlus Nord 5�5G (Marble Sands, 256 GB)
# 93                                 MOTOROLA Edge 50 (Koala Grey, 256 GB)
# 94                               MOTOROLA Edge 50 (Jungle Green, 256 GB)
# 95                                 MOTOROLA Edge 50 (Peach Fuzz, 256 GB)
# 96                                   OnePlus Nord 5 5G (Dry Ice, 256 GB)
# 97             MOTOROLA Edge 60 Fusion 5G (PANTONE Mykonos Blue, 256 GB)
# 98                   MOTOROLA Edge 60 Fusion 5G (PANTONE Zephyr, 256 GB)
# 99                MOTOROLA Edge 60 Fusion 5G (PANTONE Amazonite, 256 GB)
# 100              MOTOROLA Edge 60 Fusion 5G (PANTONE Slipstream, 256 GB)
# 101                                    OPPO Reno13 5G (Sky Blue, 256 GB)
# 102                            OnePlus Nord CE4 (Celadon Marble, 128 GB)
# 103                            OnePlus Nord CE4 (Celadon Marble, 256 GB)
# 104                               OnePlus Nord CE4 (Dark Chrome, 128 GB)
# 105                               OnePlus Nord CE4 (Dark Chrome, 256 GB)
# 106                             OnePlus Nord CE3 5G (Aqua Surge, 128 GB)
# 107                                          Honor Holly 3 (Gold, 32 GB)
# 108                                         Honor Holly 3 (Black, 32 GB)
# 109                                         Honor Holly 3 (White, 32 GB)
# 110                                 OPPO Reno14 5G (Pearl White, 256 GB)
# 111                                OPPO Reno14 5G (Forest Green, 256 GB)
# 112                                  OPPO Reno14 5G (Mint Green, 256 GB)
# 113                                OnePlus Nord 2T 5G (Jade Fog, 128 GB)
# 114                             OnePlus Nord 2T 5G (Gray Shadow, 128 GB)
# 115                              OnePlus Nord 3 5G (Misty Green, 128 GB)
# 116                             OnePlus Nord 3 5G (Tempest Gray, 128 GB)
# 117                            OnePlus Nord CE5 5G (Marble Mist, 128 GB)
# 118                         OnePlus Nord CE5 5G (Black Infinity, 128 GB)
# 119                             OnePlus Nord CE5 5G (Nexus Blue, 128 GB)
# 120                             OnePlus Nord 5 5G (Phantom Grey, 512 GB)
# 121                             OnePlus Nord 5 5G (Marble Sands, 256 GB)
# 122                             OnePlus Nord 5 5G (Phantom Grey, 256 GB)
# 123                            OnePlus Nord CE5 5G (Marble Mist, 256 GB)
# 124                             OnePlus Nord CE5 5G (Nexus Blue, 256 GB)
# 125                             OnePlus 8 Pro (Ultramarine Blue, 256 GB)
# 126                               OPPO F25 Pro 5G (Coral Purple, 128 GB)
# 127                        OPPO K13 Turbo Pro 5G (Silver Knight, 256 GB)
# 128                                      OnePlus 12R (Cool Blue, 128 GB)
# 129                                    OnePlus 12R (Sunset Dune, 256 GB)
# 130                                 OnePlus 9RT 5G (Nano Silver, 128 GB)
# 131                            OPPO Reno 12 Pro 5G (Space Brown, 512 GB)
# 132        OPPO Reno 12 Pro 5G (Manish Malhotra Limited Edition, 256 GB)
# 133                         OnePlus Nord CE4 lite 5G (MEGA BLUE, 256 GB)
# 134                      OnePlus Nord CE4 lite 5G (SUPER SILVER, 256 GB)
# 135                             OnePlus 8T 5G (Aquamarine Green, 256 GB)
# 136                                 OnePlus 8T 5G (Lunar Silver, 256 GB)
# 137                             OnePlus Nord CE3 5G (Aqua Surge, 256 GB)
# 138                                 OnePlus 9R 5G (Carbon Black, 128 GB)
# 139                                    OnePlus 9R 5G (Lake Blue, 128 GB)
# 140                        OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)
# 141                                  OnePlus 11 5G (Titan Black, 128 GB)
# 142                                OnePlus 11 5G (Eternal Green, 128 GB)
# 143                        OnePlus Nord 4 5G (Obsidian Midnight, 256 GB)
# 144                         OnePlus Nord 4 5G (Mercurial Silver, 256 GB)
# 145                              OnePlus Nord 4 5G (Oasis Green, 256 GB)
# 146                               Honor 200 5G (Moonlight White, 256 GB)
# 147                                         Honor 200 5G (Black, 256 GB)
# 148                                   OnePlus 10R (Sierra Black, 128 GB)
# 149                                   OnePlus 10R (Forest Green, 128 GB)
# 150                                OnePlus Nord 2T 5G (Jade Fog, 256 GB)
# 151                             OnePlus Nord 2T 5G (Gray Shadow, 256 GB)
# 152                           OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)
# 153                           OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)
# 154                        MOTOROLA Edge 60 Pro (Pantone Shadow, 512 GB)
# 155               MOTOROLA Edge 60 Pro (Pantone Sparkling Grape, 512 GB)
# 156                        MOTOROLA Edge 60 Pro (Pantone Walnut, 512 GB)
# 157                 MOTOROLA Edge 60 Pro (Pantone Dazzling Blue, 512 GB)
# 158                                OPPO Reno 12 5G (Matte Brown, 256 GB)
# 159                         OnePlus Nord CE5 5G (Black Infinity, 256 GB)
# 160                                    OPPO F27 Pro+ (Dusk Pink, 256 GB)
# 161                                    OPPO F27 Pro+ (Dusk Pink, 128 GB)
# 162                               OPPO F29 Pro 5G (Marble White, 128 GB)
# 163                              OPPO F29 Pro 5G (Granite Black, 128 GB)
# 164                                               Honor 7C (Blue, 32 GB)
# 165                                               Honor 7C (Gold, 32 GB)
# 166                               OPPO F29 Pro 5G (Marble White, 256 GB)
# 167                              OPPO F29 Pro 5G (Granite Black, 256 GB)
# 168                             OnePlus Nord 3 5G (Tempest Gray, 256 GB)
# 169                              OnePlus Nord 3 5G (Misty Green, 256 GB)
# 170                             OPPO K13 Turbo 5G (White Knight, 256 GB)
# 171                        OPPO K13 Turbo 5G (Midnight Maverick, 128 GB)
# 172                        OPPO K13 Turbo 5G (Midnight Maverick, 256 GB)
# 173                           OPPO K13 Turbo 5G (Purple Phantom, 256 GB)
# 174                           OPPO K13 Turbo 5G (Purple Phantom, 128 GB)
# 175                             OPPO K13 Turbo 5G (White Knight, 128 GB)
# 176                                               Honor 7C (Gold, 64 GB)
# 177                                   OPPO F27 5G (Amber Orange, 256 GB)
# 178                                OnePlus 10R 5G (Sierra Black, 256 GB)
# 179                                   OPPO F29 5G (Glacier Blue, 256 GB)
# 180                                   OPPO F29 5G (Glacier Blue, 128 GB)
# 181                                   OPPO F29 5G (Solid Purple, 256 GB)
# 182                                   OPPO F29 5G (Solid Purple, 128 GB)
# 183                                   Honor X9b (Midnight Black, 256 GB)
# 184                                   Honor X9b (Sunrise Orange, 256 GB)
# 185                           OnePlus 10 Pro 5G (Emerald Forest, 128 GB)
# 186                           OnePlus 10 Pro 5G (Volcanic Black, 128 GB)
# 187                             OnePlus 10T 5G (Moonstone Black, 128 GB)
#
#      Product_ID Sentiment  Sentiment_Score   Ratings  Reviews
# 0           123  Positive         0.896708  4.230000       50
# 1           145  Positive         0.886284  4.490000       50
# 2           133  Positive         0.886284  4.490000       50
# 3           148  Positive         0.845856  4.710000       50
# 4           152  Positive         0.845856  4.710000       50
# 5           158  Positive         0.845856  4.710000       50
# 6           136  Positive         0.840244  4.590000       50
# 7           131  Positive         0.840244  4.590000       50
# 8           138  Positive         0.840244  4.590000       50
# 9           134  Positive         0.819048  4.700000       50
# 10          140  Positive         0.819048  4.700000       50
# 11           52  Positive         0.798476  4.600000       50
# 12           64  Positive         0.789612  4.490000       50
# 13          132  Positive         0.779780  4.740000       50
# 14          147  Positive         0.779780  4.740000       50
# 15          135  Positive         0.779780  4.740000       50
# 16           47  Positive         0.769474  4.690000       50
# 17           38  Positive         0.769474  4.690000       50
# 18          130  Positive         0.754250  4.630000       50
# 19           31  Positive         0.749444  4.640000       50
# 20           57  Positive         0.749014  4.306122       49
# 21           39  Positive         0.749014  4.306122       49
# 22          142  Positive         0.740580  4.750000       50
# 23           66  Positive         0.740278  4.610000       50
# 24            9  Positive         0.740278  4.610000       50
# 25           25  Positive         0.740278  4.610000       50
# 26           45  Positive         0.738994  4.580000       50
# 27           36  Positive         0.738994  4.580000       50
# 28           40  Positive         0.738994  4.580000       50
# 29           26  Positive         0.738994  4.580000       50
# 30           54  Positive         0.730422  4.580000       50
# 31           65  Positive         0.729784  4.580000       50
# 32           55  Positive         0.729784  4.580000       50
# 33          159  Positive         0.725710  4.500000       50
# 34          151  Positive         0.725710  4.500000       50
# 35          157  Positive         0.725710  4.500000       50
# 36          155  Positive         0.725710  4.500000       50
# 37           30  Positive         0.721659  4.612245       49
# 38           27  Positive         0.721659  4.612245       49
# 39           37  Positive         0.721659  4.612245       49
# 40           16  Positive         0.721659  4.612245       49
# 41           29  Positive         0.721659  4.612245       49
# 42          118  Positive         0.718425  4.850000        4
# 43          119  Positive         0.718425  4.850000        4
# 44           46  Positive         0.712098  4.494792       96
# 45           41  Positive         0.712098  4.494792       96
# 46          154  Positive         0.710480  4.690000       50
# 47           61  Positive         0.708300  4.550000       50
# 48           34  Positive         0.708300  4.550000       50
# 49           53  Positive         0.708300  4.550000       50
# 50           60  Positive         0.708300  4.550000       50
# 51           33  Positive         0.705754  4.670000       50
# 52           62  Positive         0.705754  4.670000       50
# 53           35  Positive         0.705754  4.670000       50
# 54           32  Positive         0.705754  4.670000       50
# 55          153  Positive         0.689822  4.490000       50
# 56          150  Positive         0.689822  4.490000       50
# 57          149  Positive         0.689822  4.490000       50
# 58          156  Positive         0.689822  4.490000       50
# 59            3  Positive         0.683376  4.740000       50
# 60            7  Positive         0.683376  4.740000       50
# 61            2  Positive         0.683376  4.740000       50
# 62            5  Positive         0.683376  4.740000       50
# 63          162  Positive         0.683300  4.850000        4
# 64          160  Positive         0.683300  4.850000        4
# 65           48  Positive         0.682840  4.520000       50
# 66           49  Positive         0.682840  4.520000       50
# 67           28  Positive         0.665308  4.540000       50
# 68           44  Positive         0.665308  4.540000       50
# 69           43  Positive         0.665308  4.540000       50
# 70           42  Positive         0.659018  4.650000       50
# 71           63  Positive         0.659018  4.650000       50
# 72           58  Positive         0.659018  4.650000       50
# 73           51  Positive         0.659018  4.650000       50
# 74          146  Positive         0.651067  4.833333       48
# 75           11  Positive         0.647285  4.561224       98
# 76           19  Positive         0.647285  4.561224       98
# 77           21  Positive         0.647285  4.561224       98
# 78           13  Positive         0.647285  4.561224       98
# 79          116  Positive         0.642295  4.801136      176
# 80          101  Positive         0.640707  4.800000      175
# 81           12  Positive         0.633068  4.630000       50
# 82           10  Positive         0.633068  4.630000       50
# 83          181  Positive         0.631102  4.473404      188
# 84          125  Positive         0.627883  4.541667       48
# 85          124  Positive         0.627883  4.541667       48
# 86          127  Positive         0.624968  4.425532       47
# 87          126  Positive         0.624968  4.425532       47
# 88           15  Positive         0.624068  4.410000       50
# 89           59  Positive         0.618480  4.340000       50
# 90           50  Positive         0.618480  4.340000       50
# 91           56  Positive         0.618480  4.340000       50
# 92           81  Positive         0.614644  4.722222       18
# 93           22  Positive         0.606930  4.370000       50
# 94           18  Positive         0.606930  4.370000       50
# 95           17  Positive         0.606930  4.370000       50
# 96           78  Positive         0.604942  4.575758       33
# 97            6  Positive         0.602578  4.704082       98
# 98            4  Positive         0.602578  4.704082       98
# 99            8  Positive         0.602578  4.704082       98
# 100           1  Positive         0.602578  4.704082       98
# 101         180  Positive         0.597764  4.554595      185
# 102          83  Positive         0.596859  4.604520      177
# 103          85  Positive         0.596859  4.604520      177
# 104          76  Positive         0.596859  4.604520      177
# 105          80  Positive         0.596859  4.604520      177
# 106          96  Positive         0.593809  4.566474      173
# 107         137  Positive         0.592451  4.355556       45
# 108         139  Positive         0.592451  4.355556       45
# 109         143  Positive         0.592451  4.355556       45
# 110         167  Positive         0.588656  4.633679      193
# 111         166  Positive         0.588656  4.633679      193
# 112         168  Positive         0.588656  4.633679      193
# 113         102  Positive         0.587271  4.611765      170
# 114          98  Positive         0.587271  4.611765      170
# 115          87  Positive         0.576187  4.509615      104
# 116         103  Positive         0.576187  4.509615      104
# 117          73  Positive         0.564834  4.450000       80
# 118          68  Positive         0.564834  4.450000       80
# 119          75  Positive         0.564834  4.450000       80
# 120          74  Positive         0.551895  4.631579       19
# 121          71  Positive         0.551895  4.631579       19
# 122          70  Positive         0.551895  4.631579       19
# 123          67  Positive         0.548230  4.373626       91
# 124          69  Positive         0.548230  4.373626       91
# 125          86  Positive         0.545733  4.666667        3
# 126         188  Positive         0.542884  4.442718      103
# 127         184  Positive         0.542155  4.630000       20
# 128         113  Positive         0.539108  4.429379      177
# 129         117  Positive         0.539108  4.429379      177
# 130         112  Positive         0.527227  4.533333       45
# 131         186  Positive         0.524461  4.432258      155
# 132         187  Positive         0.524461  4.432258      155
# 133         115   Neutral         0.510289  4.370861      151
# 134          77  Positive         0.510289  4.370861      151
# 135          95  Positive         0.500056  4.000000        9
# 136          90  Positive         0.500056  4.000000        9
# 137          97  Positive         0.499734  4.344595      148
# 138          99  Positive         0.483200  4.100000       10
# 139          84  Positive         0.483200  4.100000       10
# 140          89  Positive         0.482896  4.417266      139
# 141         109  Positive         0.479311  4.333333       90
# 142          92  Positive         0.479311  4.333333       90
# 143          79  Positive         0.478688  4.308989      178
# 144          82  Positive         0.478688  4.308989      178
# 145          94  Positive         0.478688  4.308989      178
# 146         121  Positive         0.474806  4.505882       17
# 147         120  Positive         0.474806  4.505882       17
# 148         108  Positive         0.472813  4.287500      160
# 149         111  Positive         0.472813  4.287500      160
# 150         114  Positive         0.471517  4.424460      139
# 151          91  Positive         0.471517  4.424460      139
# 152          93  Positive         0.471396  4.237374      198
# 153         106  Positive         0.460729  4.244898       49
# 154          14  Positive         0.439127  4.106667       30
# 155          20  Positive         0.439127  4.106667       30
# 156          24  Positive         0.439127  4.106667       30
# 157          23  Positive         0.439127  4.106667       30
# 158         179  Positive         0.432256  4.334545      165
# 159          72  Positive         0.428008  3.923077       13
# 160         161  Positive         0.414745  4.217834      157
# 161         165  Positive         0.414745  4.217834      157
# 162         177  Positive         0.412805  4.140476       84
# 163         170  Positive         0.412805  4.140476       84
# 164         128  Positive         0.411398  4.434783       46
# 165         141  Positive         0.411398  4.434783       46
# 166         173  Positive         0.410711  4.274766      107
# 167         174  Positive         0.410711  4.274766      107
# 168         100  Positive         0.397501  4.177966      118
# 169         105  Positive         0.397501  4.177966      118
# 170         163  Positive         0.395650  4.515000       60
# 171         176  Positive         0.395650  4.515000       60
# 172         164  Positive         0.395650  4.515000       60
# 173         169  Positive         0.395650  4.515000       60
# 174         182  Positive         0.395650  4.515000       60
# 175         171  Positive         0.395650  4.515000       60
# 176         144  Positive         0.395530  4.306818       44
# 177         185  Positive         0.364466  4.040964       83
# 178          88  Positive         0.353506  4.056000      125
# 179         172  Positive         0.310763  4.039506       81
# 180         183  Positive         0.310763  4.039506       81
# 181         175  Positive         0.310763  4.039506       81
# 182         178  Positive         0.310763  4.039506       81
# 183         122  Positive         0.278911  3.522222       45
# 184         129  Positive         0.278911  3.522222       45
# 185         104  Positive         0.231343  3.673913       46
# 186         110  Positive         0.231343  3.673913       46
# 187         107  Positive         0.210175  4.125000       16
